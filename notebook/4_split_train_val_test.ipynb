# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PARENT_PATH = "/content/drive/MyDrive/CSE-284-Final-Project"

# %%
import pandas as pd
import numpy as np

# Load the data from the tsv file
data = pd.read_csv(PARENT_PATH + '/data/igsr_samples.tsv', sep='\t')
data = data[data['Data collections'].str.contains("1000 Genomes phase 3 release", na=False)]

# Group by Population code
grouped = data.groupby(['Population code', 'Sex'])

# Initialize a list to collect the rows for the final DataFrame
rows_list = []

# Iterate through each population group
for (population, sex), group in grouped:
    # Shuffle the samples within the group
    group = group.sample(frac=1, random_state=0).reset_index(drop=True)
    total_samples = len(group)
    # Calculate the number of samples for each split
    train_size = int(total_samples * 0.8)
    val_size = int(total_samples * 0.1)
    # The rest will go to test, ensuring we correctly handle rounding

    # Assign samples to training, validation, and testing sets and collect them
    for idx, row in group.iterrows():
        if idx < train_size:
            split = 0  # Training
        elif idx < train_size + val_size:
            split = 1  # Validation
        else:
            split = 2  # Testing
        rows_list.append({'Sample_name': row['Sample name'],
                          'Population_code': population,
                          'Superpopulation_code': row['Superpopulation code'],
                          'Split': split,
                          'Sex': row['Sex']
                          })

# Create a DataFrame from the collected rows
results_df = pd.DataFrame(rows_list)
results_df
# Out:
#      Sample_name Population_code Superpopulation_code  Split     Sex
# 0        HG01883             ACB                  AFR      0  female
# 1        HG02580             ACB                  AFR      0  female
# 2        HG02419             ACB                  AFR      0  female
# 3        HG02095             ACB                  AFR      0  female
# 4        HG02315             ACB                  AFR      0  female
# ...          ...             ...                  ...    ...     ...
# 3110     NA19186             YRI                  AFR      2    male
# 3111     NA19207             YRI                  AFR      2    male
# 3112     NA19173             YRI                  AFR      2    male
# 3113     NA18521             YRI                  AFR      2    male
# 3114     NA18485             YRI                  AFR      2    male
#
# [3115 rows x 5 columns]

# %%
results_df.to_csv('split_samples.csv', index=False)

# %%
! cp split_samples.csv /content/drive/MyDrive/CSE-284-Final-Project/data

# %%
! mkdir split_ids
! mkdir split_ids/by_superpopulation
! mkdir split_ids/by_population

# %%
sh = """

SPLIT_CSV=/content/split_samples.csv
OUT_DIR=/content/split_ids/by_superpopulation/

for SUPERPOP in "AFR" "AMR" "EAS" "EUR" "SAS"

do

    # Print header
    echo "#FID IID" > ${OUT_DIR}${SUPERPOP}_train.txt
    # Process and filter for training set
    awk -F"," -v superpop="$SUPERPOP" '($3==superpop && $4=="0") {print $3"_"$2, $1}' $SPLIT_CSV >> ${OUT_DIR}${SUPERPOP}_train.txt

    # Print header
    echo "#FID IID" > ${OUT_DIR}${SUPERPOP}_val.txt
    # Process and filter for training set
    awk -F"," -v superpop="$SUPERPOP" '($3==superpop && $4=="1") {print $3"_"$2, $1}' $SPLIT_CSV >> ${OUT_DIR}${SUPERPOP}_val.txt

    # Print header
    echo "#FID IID" > ${OUT_DIR}${SUPERPOP}_test.txt
    # Process and filter for training set
    awk -F"," -v superpop="$SUPERPOP" '($3==superpop && $4=="2") {print $3"_"$2, $1}' $SPLIT_CSV >> ${OUT_DIR}${SUPERPOP}_test.txt

done

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh

# %%
# sh = """

# SPLIT_CSV=/content/split_samples.csv
# OUT_DIR=/content/split_ids/by_superpopulation/

# for SUPERPOP in "AFR" "AMR" "EAS" "EUR" "SAS"

# do
#    # For training data
#    awk -F"," -v superpop="$SUPERPOP" '($3==superpop && $4=="0") \
#         {print $1}' $SPLIT_CSV > ${OUT_DIR}${SUPERPOP}_train.txt

#    # For validation data
#    awk -F"," -v superpop="$SUPERPOP" '($3==superpop && $4=="1") \
#         {print $1}' $SPLIT_CSV > ${OUT_DIR}${SUPERPOP}_val.txt

#    # For test data
#    awk -F"," -v superpop="$SUPERPOP" '($3==superpop && $4=="2") \
#         {print $1}' $SPLIT_CSV > ${OUT_DIR}${SUPERPOP}_test.txt

# done

# """
# with open('script.sh', 'w') as file:
#   file.write(sh)

# ! bash script.sh

# %%
sh = """

SPLIT_CSV=/content/split_samples.csv
OUT_DIR=/content/split_ids/by_population/

for POP in "ACB" "ASW" "BEB" "CDX" "CEU" "CHB" "CHS" "CLM" "ESN" "FIN" "GBR" "GIH" "GWD" "IBS" "ITU" "JPT" "KHV" "LWK" "MSL" "MXL" "PEL" "PJL" "PUR" "STU" "TSI" "YRI"

do
    # For all data (no splitting)
    # Print header
    echo "#FID IID" > ${OUT_DIR}${POP}_all.txt
    # Process and filter for training set
    awk -F"," -v pop="$POP" '($2==pop) {print $3"_"$2, $1}' $SPLIT_CSV >> ${OUT_DIR}${POP}_all.txt


    # Print header
    echo "#FID IID" > ${OUT_DIR}${POP}_train.txt
    # Process and filter for training set
    awk -F"," -v pop="$POP" '($2==pop && $4=="0") {print $3"_"$2, $1}' $SPLIT_CSV >> ${OUT_DIR}${POP}_train.txt

    # Print header
    echo "#FID IID" > ${OUT_DIR}${POP}_val.txt
    # Process and filter for training set
    awk -F"," -v pop="$POP" '($2==pop && $4=="1") {print $3"_"$2, $1}' $SPLIT_CSV >> ${OUT_DIR}${POP}_val.txt

    # Print header
    echo "#FID IID" > ${OUT_DIR}${POP}_test.txt
    # Process and filter for training set
    awk -F"," -v pop="$POP" '($2==pop && $4=="2") {print $3"_"$2, $1}' $SPLIT_CSV >> ${OUT_DIR}${POP}_test.txt

done

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh

# %%
! cp -rf split_ids/ /content/drive/MyDrive/CSE-284-Final-Project/data/

# %%
! wget https://s3.amazonaws.com/plink2-assets/alpha5/plink2_linux_x86_64_20240105.zip
! unzip plink2_linux_x86_64_20240105.zip
! ./plink2
# Out:
# --2024-03-06 21:26:48--  https://s3.amazonaws.com/plink2-assets/alpha5/plink2_linux_x86_64_20240105.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.136.208, 54.231.225.56, 54.231.163.24, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.136.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9266484 (8.8M) [application/zip]
# Saving to: ‘plink2_linux_x86_64_20240105.zip’
#
# plink2_linux_x86_64 100%[===================>]   8.84M  16.1MB/s    in 0.5s
#
# 2024-03-06 21:26:49 (16.1 MB/s) - ‘plink2_linux_x86_64_20240105.zip’ saved [9266484/9266484]
#
# Archive:  plink2_linux_x86_64_20240105.zip
#   inflating: plink2
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
#
#   plink2 <input flag(s)...> [command flag(s)...] [other flag(s)...]
#   plink2 --help [flag name(s)...]
#
# Commands include --rm-dup list, --make-bpgen, --export, --freq, --geno-counts,
# --sample-counts, --missing, --hardy, --het, --fst, --indep-pairwise, --ld,
# --sample-diff, --make-king, --king-cutoff, --pmerge, --pgen-diff,
# --write-samples, --write-snplist, --make-grm-list, --pca, --glm, --adjust-file,
# --gwas-ssf, --clump, --score, --variant-score, --genotyping-rate, --pgen-info,
# --validate, and --zst-decompress.
#
# "plink2 --help | more" describes all functions.

# %%
! cp /content/drive/MyDrive/CSE-284-Final-Project/data/1000g_combined/1000g.* .

# %%
! mkdir 1000g_by_superpopulation

# %%
sh = """

echo "." > exclude.snps

BFILE=/content/1000g
KEEP_ID_DIR=/content/split_ids/by_superpopulation
OUT_DIR=/content/1000g_by_superpopulation

for SUPERPOP in "AFR" "AMR" "EAS" "EUR" "SAS"

do

    for SPLIT in "train" "val" "test"

    do
        ./plink2 \
            --make-pgen vzs 'pvar-cols=' \
            --keep ${KEEP_ID_DIR}/${SUPERPOP}_${SPLIT}.txt \
            --max-alleles 2 \
            --maf 0.01 \
            --bfile $BFILE \
            --snps-only just-acgt \
            --rm-dup exclude-all \
            --exclude exclude.snps \
            --out ${OUT_DIR}/${SUPERPOP}_${SPLIT}
    done

done

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AFR_train.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AFR_train.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AFR_train
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:32:34 2024
# 12978 MiB RAM detected, ~11546 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 523 samples remaining.
# 523 samples (267 females, 256 males; 520 founders) remaining after main
# filters.
# done.
# 1554794 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10568687 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AFR_train.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:33:54 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AFR_val.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AFR_val.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AFR_val
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:33:54 2024
# 12978 MiB RAM detected, ~11569 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 64 samples remaining.
# 64 samples (34 females, 30 males; 63 founders) remaining after main filters.
# done.
# 1786370 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10337111 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AFR_val.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:35:08 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AFR_test.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AFR_test.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AFR_test
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:35:08 2024
# 12978 MiB RAM detected, ~11571 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 74 samples remaining.
# 74 samples (40 females, 34 males; 73 founders) remaining after main filters.
# done.
# 1664344 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10459137 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AFR_test.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:36:21 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AMR_train.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AMR_train.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AMR_train
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:36:21 2024
# 12978 MiB RAM detected, ~11584 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 279 samples remaining.
# 279 samples (142 females, 137 males; 279 founders) remaining after main
# filters.
# done.
# 3095440 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 9028041 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AMR_train.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:37:35 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AMR_val.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AMR_val.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AMR_val
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:37:35 2024
# 12978 MiB RAM detected, ~11561 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 30 samples remaining.
# 30 samples (15 females, 15 males; 30 founders) remaining after main filters.
# done.
# 3146105 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 8977376 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AMR_val.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:38:49 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AMR_test.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AMR_test.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AMR_test
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:38:49 2024
# 12978 MiB RAM detected, ~11562 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 38 samples remaining.
# 38 samples (20 females, 18 males; 38 founders) remaining after main filters.
# done.
# 2758810 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 9364671 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AMR_test.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:40:04 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EAS_train.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EAS_train.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EAS_train
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:40:04 2024
# 12978 MiB RAM detected, ~11568 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 402 samples remaining.
# 402 samples (208 females, 194 males; 402 founders) remaining after main
# filters.
# done.
# 5420899 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6702582 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EAS_train.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:41:21 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EAS_val.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EAS_val.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EAS_val
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:41:21 2024
# 12978 MiB RAM detected, ~11574 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 50 samples remaining.
# 50 samples (26 females, 24 males; 50 founders) remaining after main filters.
# done.
# 5196783 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6926698 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EAS_val.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:42:38 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EAS_test.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EAS_test.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EAS_test
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:42:38 2024
# 12978 MiB RAM detected, ~11566 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 52 samples remaining.
# 52 samples (26 females, 26 males; 52 founders) remaining after main filters.
# done.
# 5649280 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6474201 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EAS_test.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:43:59 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EUR_train.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EUR_train.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EUR_train
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:43:59 2024
# 12978 MiB RAM detected, ~11550 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 403 samples remaining.
# 403 samples (211 females, 192 males; 403 founders) remaining after main
# filters.
# done.
# 4456349 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7667132 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EUR_train.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:45:16 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EUR_val.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EUR_val.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EUR_val
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:45:16 2024
# 12978 MiB RAM detected, ~11536 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 40 samples remaining.
# 40 samples (22 females, 18 males; 40 founders) remaining after main filters.
# done.
# 4287506 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7835975 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EUR_val.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:46:31 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EUR_test.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EUR_test.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EUR_test
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:46:31 2024
# 12978 MiB RAM detected, ~11559 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 59 samples remaining.
# 59 samples (30 females, 29 males; 59 founders) remaining after main filters.
# done.
# 4671614 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7451867 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EUR_test.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:47:45 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/SAS_train.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/SAS_train.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/SAS_train
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:47:45 2024
# 12978 MiB RAM detected, ~11572 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 387 samples remaining.
# 387 samples (182 females, 205 males; 386 founders) remaining after main
# filters.
# done.
# 4235376 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7888105 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/SAS_train.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:49:03 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/SAS_val.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/SAS_val.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/SAS_val
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:49:03 2024
# 12978 MiB RAM detected, ~11561 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 44 samples remaining.
# 44 samples (19 females, 25 males; 44 founders) remaining after main filters.
# done.
# 4143710 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7979771 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/SAS_val.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:50:21 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/SAS_test.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/SAS_test.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/SAS_test
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:50:21 2024
# 12978 MiB RAM detected, ~11567 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 58 samples remaining.
# 58 samples (28 females, 30 males; 57 founders) remaining after main filters.
# done.
# 4546722 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7576759 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/SAS_test.psam ... done.
# done.
# done.
# End time: Wed Mar  6 23:51:39 2024

# %%
sh = """

echo "." > exclude.snps

BFILE=/content/1000g
KEEP_ID_DIR=/content/split_ids/by_superpopulation
OUT_DIR=/content/1000g_by_superpopulation

for SUPERPOP in "AFR" "AMR" "EAS" "EUR" "SAS"

do

    for SPLIT in "train" "val" "test"

    do
        ./plink2 \
            --make-bed \
            --keep ${KEEP_ID_DIR}/${SUPERPOP}_${SPLIT}.txt \
            --max-alleles 2 \
            --maf 0.01 \
            --bfile $BFILE \
            --snps-only just-acgt \
            --rm-dup exclude-all \
            --exclude exclude.snps \
            --out ${OUT_DIR}/${SUPERPOP}_${SPLIT}
    done

done

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AFR_train.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AFR_train.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AFR_train
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:52:25 2024
# 12978 MiB RAM detected, ~11537 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 523 samples remaining.
# 523 samples (267 females, 256 males; 520 founders) remaining after main
# filters.
# done.
# 1554794 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10568687 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AFR_train.fam ... done.
# Writing /content/1000g_by_superpopulation/AFR_train.bim ... done.
# done.
# End time: Wed Mar  6 23:54:00 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AFR_val.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AFR_val.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AFR_val
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:54:00 2024
# 12978 MiB RAM detected, ~11558 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 64 samples remaining.
# 64 samples (34 females, 30 males; 63 founders) remaining after main filters.
# done.
# 1786370 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10337111 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AFR_val.fam ... done.
# Writing /content/1000g_by_superpopulation/AFR_val.bim ... done.
# done.
# End time: Wed Mar  6 23:55:32 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AFR_test.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AFR_test.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AFR_test
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:55:32 2024
# 12978 MiB RAM detected, ~11553 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 74 samples remaining.
# 74 samples (40 females, 34 males; 73 founders) remaining after main filters.
# done.
# 1664344 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10459137 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AFR_test.fam ... done.
# Writing /content/1000g_by_superpopulation/AFR_test.bim ... done.
# done.
# End time: Wed Mar  6 23:57:07 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AMR_train.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AMR_train.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AMR_train
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:57:08 2024
# 12978 MiB RAM detected, ~11833 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 279 samples remaining.
# 279 samples (142 females, 137 males; 279 founders) remaining after main
# filters.
# done.
# 3095440 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 9028041 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AMR_train.fam ... done.
# Writing /content/1000g_by_superpopulation/AMR_train.bim ... done.
# done.
# End time: Wed Mar  6 23:58:49 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AMR_val.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AMR_val.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AMR_val
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 23:58:49 2024
# 12978 MiB RAM detected, ~11838 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 30 samples remaining.
# 30 samples (15 females, 15 males; 30 founders) remaining after main filters.
# done.
# 3146105 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 8977376 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AMR_val.fam ... done.
# Writing /content/1000g_by_superpopulation/AMR_val.bim ... done.
# done.
# End time: Thu Mar  7 00:00:29 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/AMR_test.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/AMR_test.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/AMR_test
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:00:29 2024
# 12978 MiB RAM detected, ~11859 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 38 samples remaining.
# 38 samples (20 females, 18 males; 38 founders) remaining after main filters.
# done.
# 2758810 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 9364671 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/AMR_test.fam ... done.
# Writing /content/1000g_by_superpopulation/AMR_test.bim ... done.
# done.
# End time: Thu Mar  7 00:02:09 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EAS_train.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EAS_train.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EAS_train
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:02:09 2024
# 12978 MiB RAM detected, ~11844 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 402 samples remaining.
# 402 samples (208 females, 194 males; 402 founders) remaining after main
# filters.
# done.
# 5420899 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6702582 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EAS_train.fam ... done.
# Writing /content/1000g_by_superpopulation/EAS_train.bim ... done.
# done.
# End time: Thu Mar  7 00:03:50 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EAS_val.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EAS_val.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EAS_val
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:03:50 2024
# 12978 MiB RAM detected, ~11865 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 50 samples remaining.
# 50 samples (26 females, 24 males; 50 founders) remaining after main filters.
# done.
# 5196783 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6926698 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EAS_val.fam ... done.
# Writing /content/1000g_by_superpopulation/EAS_val.bim ... done.
# done.
# End time: Thu Mar  7 00:05:19 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EAS_test.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EAS_test.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EAS_test
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:05:19 2024
# 12978 MiB RAM detected, ~11857 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 52 samples remaining.
# 52 samples (26 females, 26 males; 52 founders) remaining after main filters.
# done.
# 5649280 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6474201 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EAS_test.fam ... done.
# Writing /content/1000g_by_superpopulation/EAS_test.bim ... done.
# done.
# End time: Thu Mar  7 00:06:47 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EUR_train.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EUR_train.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EUR_train
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:06:47 2024
# 12978 MiB RAM detected, ~11849 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 403 samples remaining.
# 403 samples (211 females, 192 males; 403 founders) remaining after main
# filters.
# done.
# 4456349 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7667132 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EUR_train.fam ... done.
# Writing /content/1000g_by_superpopulation/EUR_train.bim ... done.
# done.
# End time: Thu Mar  7 00:08:22 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EUR_val.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EUR_val.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EUR_val
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:08:22 2024
# 12978 MiB RAM detected, ~11838 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 40 samples remaining.
# 40 samples (22 females, 18 males; 40 founders) remaining after main filters.
# done.
# 4287506 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7835975 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EUR_val.fam ... done.
# Writing /content/1000g_by_superpopulation/EUR_val.bim ... done.
# done.
# End time: Thu Mar  7 00:09:54 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/EUR_test.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/EUR_test.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/EUR_test
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:09:54 2024
# 12978 MiB RAM detected, ~11839 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 59 samples remaining.
# 59 samples (30 females, 29 males; 59 founders) remaining after main filters.
# done.
# 4671614 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7451867 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/EUR_test.fam ... done.
# Writing /content/1000g_by_superpopulation/EUR_test.bim ... done.
# done.
# End time: Thu Mar  7 00:11:26 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/SAS_train.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/SAS_train.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/SAS_train
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:11:26 2024
# 12978 MiB RAM detected, ~11830 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 387 samples remaining.
# 387 samples (182 females, 205 males; 386 founders) remaining after main
# filters.
# done.
# 4235376 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7888105 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/SAS_train.fam ... done.
# Writing /content/1000g_by_superpopulation/SAS_train.bim ... done.
# done.
# End time: Thu Mar  7 00:13:03 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/SAS_val.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/SAS_val.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/SAS_val
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:13:03 2024
# 12978 MiB RAM detected, ~11846 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 44 samples remaining.
# 44 samples (19 females, 25 males; 44 founders) remaining after main filters.
# done.
# 4143710 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7979771 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/SAS_val.fam ... done.
# Writing /content/1000g_by_superpopulation/SAS_val.bim ... done.
# done.
# End time: Thu Mar  7 00:14:38 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_superpopulation/SAS_test.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_superpopulation/SAS_test.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_superpopulation/SAS_test
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:14:38 2024
# 12978 MiB RAM detected, ~11843 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 58 samples remaining.
# 58 samples (28 females, 30 males; 57 founders) remaining after main filters.
# done.
# 4546722 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7576759 variants remaining after main filters.
# Writing /content/1000g_by_superpopulation/SAS_test.fam ... done.
# Writing /content/1000g_by_superpopulation/SAS_test.bim ... done.
# done.
# End time: Thu Mar  7 00:16:07 2024

# %%
! cp -rf 1000g_by_superpopulation/ /content/drive/MyDrive/CSE-284-Final-Project/data/

# %%
! mkdir 1000g_by_population

# %%
sh = """

echo "." > exclude.snps

BFILE=/content/1000g
KEEP_ID_DIR=/content/split_ids/by_population
OUT_DIR=/content/1000g_by_population

for POP in "ACB" "ASW" "BEB" "CDX" "CEU" "CHB" "CHS" "CLM" "ESN" "FIN" "GBR" "GIH" "GWD" "IBS" "ITU" "JPT" "KHV" "LWK" "MSL" "MXL" "PEL" "PJL" "PUR" "STU" "TSI" "YRI"

    do
        ./plink2 \
            --make-pgen vzs 'pvar-cols=' \
            --keep ${KEEP_ID_DIR}/${POP}_all.txt \
            --max-alleles 2 \
            --maf 0.01 \
            --bfile $BFILE \
            --snps-only just-acgt \
            --rm-dup exclude-all \
            --exclude exclude.snps \
            --out ${OUT_DIR}/${POP}_all
    done


"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/ACB_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/ACB_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/ACB_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:33:21 2024
# 12978 MiB RAM detected, ~11692 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 96 samples remaining.
# 96 samples (49 females, 47 males; 96 founders) remaining after main filters.
# done.
# 1194786 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10928695 variants remaining after main filters.
# Writing /content/1000g_by_population/ACB_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:35:00 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/ASW_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/ASW_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/ASW_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:35:00 2024
# 12978 MiB RAM detected, ~11688 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 61 samples remaining.
# 61 samples (35 females, 26 males; 56 founders) remaining after main filters.
# done.
# 1340978 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10782503 variants remaining after main filters.
# Writing /content/1000g_by_population/ASW_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:36:36 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/BEB_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/BEB_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/BEB_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:36:36 2024
# 12978 MiB RAM detected, ~11688 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 86 samples remaining.
# 86 samples (44 females, 42 males; 86 founders) remaining after main filters.
# done.
# 4188576 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7934905 variants remaining after main filters.
# Writing /content/1000g_by_population/BEB_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:38:11 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/CDX_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/CDX_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/CDX_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:38:11 2024
# 12978 MiB RAM detected, ~11864 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 93 samples remaining.
# 93 samples (49 females, 44 males; 93 founders) remaining after main filters.
# done.
# 5413784 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6709697 variants remaining after main filters.
# Writing /content/1000g_by_population/CDX_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:39:46 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/CEU_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/CEU_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/CEU_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:39:46 2024
# 12978 MiB RAM detected, ~11856 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 99 samples remaining.
# 99 samples (50 females, 49 males; 99 founders) remaining after main filters.
# done.
# 4465952 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7657529 variants remaining after main filters.
# Writing /content/1000g_by_population/CEU_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:41:24 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/CHB_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/CHB_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/CHB_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:41:24 2024
# 12978 MiB RAM detected, ~11846 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 103 samples remaining.
# 103 samples (57 females, 46 males; 103 founders) remaining after main filters.
# done.
# 5571901 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6551580 variants remaining after main filters.
# Writing /content/1000g_by_population/CHB_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:43:00 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/CHS_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/CHS_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/CHS_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:43:00 2024
# 12978 MiB RAM detected, ~11867 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 105 samples remaining.
# 105 samples (53 females, 52 males; 105 founders) remaining after main filters.
# done.
# 5603399 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6520082 variants remaining after main filters.
# Writing /content/1000g_by_population/CHS_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:44:46 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/CLM_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/CLM_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/CLM_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:44:47 2024
# 12978 MiB RAM detected, ~11846 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 94 samples remaining.
# 94 samples (51 females, 43 males; 94 founders) remaining after main filters.
# done.
# 2713357 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 9410124 variants remaining after main filters.
# Writing /content/1000g_by_population/CLM_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:46:41 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/ESN_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/ESN_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/ESN_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:46:41 2024
# 12978 MiB RAM detected, ~11870 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 99 samples remaining.
# 99 samples (45 females, 54 males; 99 founders) remaining after main filters.
# done.
# 1823017 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10300464 variants remaining after main filters.
# Writing /content/1000g_by_population/ESN_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:48:22 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/FIN_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/FIN_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/FIN_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:48:22 2024
# 12978 MiB RAM detected, ~11841 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 99 samples remaining.
# 99 samples (61 females, 38 males; 99 founders) remaining after main filters.
# done.
# 4498152 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7625329 variants remaining after main filters.
# Writing /content/1000g_by_population/FIN_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:50:02 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/GBR_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/GBR_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/GBR_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:50:03 2024
# 12978 MiB RAM detected, ~11861 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 91 samples remaining.
# 91 samples (45 females, 46 males; 91 founders) remaining after main filters.
# done.
# 4532400 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7591081 variants remaining after main filters.
# Writing /content/1000g_by_population/GBR_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:51:43 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/GIH_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/GIH_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/GIH_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:51:43 2024
# 12978 MiB RAM detected, ~11828 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 103 samples remaining.
# 103 samples (47 females, 56 males; 102 founders) remaining after main filters.
# done.
# 4532715 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7590766 variants remaining after main filters.
# Writing /content/1000g_by_population/GIH_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:53:23 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/GWD_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/GWD_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/GWD_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:53:23 2024
# 12978 MiB RAM detected, ~11833 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 113 samples remaining.
# 113 samples (58 females, 55 males; 113 founders) remaining after main filters.
# done.
# 1875727 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10247754 variants remaining after main filters.
# Writing /content/1000g_by_population/GWD_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:55:06 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/IBS_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/IBS_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/IBS_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:55:06 2024
# 12978 MiB RAM detected, ~11845 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 106 samples remaining.
# 106 samples (53 females, 53 males; 106 founders) remaining after main filters.
# done.
# 4497656 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7625825 variants remaining after main filters.
# Writing /content/1000g_by_population/IBS_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:56:46 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/ITU_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/ITU_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/ITU_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:56:46 2024
# 12978 MiB RAM detected, ~11866 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 102 samples remaining.
# 102 samples (43 females, 59 males; 102 founders) remaining after main filters.
# done.
# 4538996 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7584485 variants remaining after main filters.
# Writing /content/1000g_by_population/ITU_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 00:58:32 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/JPT_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/JPT_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/JPT_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 00:58:32 2024
# 12978 MiB RAM detected, ~11864 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 104 samples remaining.
# 104 samples (48 females, 56 males; 104 founders) remaining after main filters.
# done.
# 5619812 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6503669 variants remaining after main filters.
# Writing /content/1000g_by_population/JPT_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 01:00:32 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/KHV_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/KHV_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/KHV_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:00:32 2024
# 12978 MiB RAM detected, ~11865 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 99 samples remaining.
# 99 samples (53 females, 46 males; 99 founders) remaining after main filters.
# done.
# 5259528 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6863953 variants remaining after main filters.
# Writing /content/1000g_by_population/KHV_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 01:02:32 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/LWK_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/LWK_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/LWK_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:02:32 2024
# 12978 MiB RAM detected, ~11855 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 99 samples remaining.
# 99 samples (55 females, 44 males; 99 founders) remaining after main filters.
# done.
# 1585869 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10537612 variants remaining after main filters.
# Writing /content/1000g_by_population/LWK_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 01:04:32 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/MSL_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/MSL_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/MSL_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:04:32 2024
# 12978 MiB RAM detected, ~11856 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 85 samples remaining.
# 85 samples (43 females, 42 males; 85 founders) remaining after main filters.
# done.
# 1826202 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10297279 variants remaining after main filters.
# Writing /content/1000g_by_population/MSL_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 01:06:31 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/MXL_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/MXL_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/MXL_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:06:31 2024
# 12978 MiB RAM detected, ~11883 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 64 samples remaining.
# 64 samples (32 females, 32 males; 64 founders) remaining after main filters.
# done.
# 4052522 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 8070959 variants remaining after main filters.
# Writing /content/1000g_by_population/MXL_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 01:08:25 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/PEL_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/PEL_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/PEL_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:08:25 2024
# 12978 MiB RAM detected, ~11876 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 85 samples remaining.
# 85 samples (44 females, 41 males; 85 founders) remaining after main filters.
# done.
# 4366885 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7756596 variants remaining after main filters.
# Writing /content/1000g_by_population/PEL_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 01:10:10 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/PJL_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/PJL_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/PJL_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:10:10 2024
# 12978 MiB RAM detected, ~11867 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 96 samples remaining.
# 96 samples (48 females, 48 males; 96 founders) remaining after main filters.
# done.
# 4138346 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7985135 variants remaining after main filters.
# Writing /content/1000g_by_population/PJL_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 01:11:59 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/PUR_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/PUR_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/PUR_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:11:59 2024
# 12978 MiB RAM detected, ~11852 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 104 samples remaining.
# 104 samples (50 females, 54 males; 104 founders) remaining after main filters.
# done.
# 2706563 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 9416918 variants remaining after main filters.
# Writing /content/1000g_by_population/PUR_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 01:14:02 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/STU_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/STU_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/STU_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:14:03 2024
# 12978 MiB RAM detected, ~11868 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 102 samples remaining.
# 102 samples (47 females, 55 males; 101 founders) remaining after main filters.
# done.
# 4541219 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7582262 variants remaining after main filters.
# Writing /content/1000g_by_population/STU_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 01:16:08 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/TSI_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/TSI_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/TSI_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:16:08 2024
# 12978 MiB RAM detected, ~11854 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 107 samples remaining.
# 107 samples (54 females, 53 males; 107 founders) remaining after main filters.
# done.
# 4561860 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7561621 variants remaining after main filters.
# Writing /content/1000g_by_population/TSI_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 01:18:14 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/YRI_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/YRI_all.txt
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/1000g_by_population/YRI_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:18:14 2024
# 12978 MiB RAM detected, ~11830 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 108 samples remaining.
# 108 samples (56 females, 52 males; 108 founders) remaining after main filters.
# done.
# 1931775 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10191706 variants remaining after main filters.
# Writing /content/1000g_by_population/YRI_all.psam ... done.
# done.
# done.
# End time: Thu Mar  7 01:20:05 2024

# %%
sh = """

echo "." > exclude.snps

BFILE=/content/1000g
KEEP_ID_DIR=/content/split_ids/by_population
OUT_DIR=/content/1000g_by_population

for POP in "ACB" "ASW" "BEB" "CDX" "CEU" "CHB" "CHS" "CLM" "ESN" "FIN" "GBR" "GIH" "GWD" "IBS" "ITU" "JPT" "KHV" "LWK" "MSL" "MXL" "PEL" "PJL" "PUR" "STU" "TSI" "YRI"

    do
        ./plink2 \
            --make-bed \
            --keep ${KEEP_ID_DIR}/${POP}_all.txt \
            --max-alleles 2 \
            --maf 0.01 \
            --bfile $BFILE \
            --snps-only just-acgt \
            --rm-dup exclude-all \
            --exclude exclude.snps \
            --out ${OUT_DIR}/${POP}_all
    done


"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/ACB_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/ACB_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/ACB_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:20:05 2024
# 12978 MiB RAM detected, ~11879 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 96 samples remaining.
# 96 samples (49 females, 47 males; 96 founders) remaining after main filters.
# done.
# 1194786 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10928695 variants remaining after main filters.
# Writing /content/1000g_by_population/ACB_all.fam ... done.
# Writing /content/1000g_by_population/ACB_all.bim ... done.
# done.
# End time: Thu Mar  7 01:22:21 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/ASW_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/ASW_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/ASW_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:22:21 2024
# 12978 MiB RAM detected, ~11860 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 61 samples remaining.
# 61 samples (35 females, 26 males; 56 founders) remaining after main filters.
# done.
# 1340978 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10782503 variants remaining after main filters.
# Writing /content/1000g_by_population/ASW_all.fam ... done.
# Writing /content/1000g_by_population/ASW_all.bim ... done.
# done.
# End time: Thu Mar  7 01:24:38 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/BEB_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/BEB_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/BEB_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:24:38 2024
# 12978 MiB RAM detected, ~11887 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 86 samples remaining.
# 86 samples (44 females, 42 males; 86 founders) remaining after main filters.
# done.
# 4188576 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7934905 variants remaining after main filters.
# Writing /content/1000g_by_population/BEB_all.fam ... done.
# Writing /content/1000g_by_population/BEB_all.bim ... done.
# done.
# End time: Thu Mar  7 01:26:46 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/CDX_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/CDX_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/CDX_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:26:46 2024
# 12978 MiB RAM detected, ~11867 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 93 samples remaining.
# 93 samples (49 females, 44 males; 93 founders) remaining after main filters.
# done.
# 5413784 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6709697 variants remaining after main filters.
# Writing /content/1000g_by_population/CDX_all.fam ... done.
# Writing /content/1000g_by_population/CDX_all.bim ... done.
# done.
# End time: Thu Mar  7 01:28:56 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/CEU_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/CEU_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/CEU_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:28:56 2024
# 12978 MiB RAM detected, ~11864 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 99 samples remaining.
# 99 samples (50 females, 49 males; 99 founders) remaining after main filters.
# done.
# 4465952 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7657529 variants remaining after main filters.
# Writing /content/1000g_by_population/CEU_all.fam ... done.
# Writing /content/1000g_by_population/CEU_all.bim ... done.
# done.
# End time: Thu Mar  7 01:31:11 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/CHB_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/CHB_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/CHB_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:31:12 2024
# 12978 MiB RAM detected, ~11849 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 103 samples remaining.
# 103 samples (57 females, 46 males; 103 founders) remaining after main filters.
# done.
# 5571901 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6551580 variants remaining after main filters.
# Writing /content/1000g_by_population/CHB_all.fam ... done.
# Writing /content/1000g_by_population/CHB_all.bim ... done.
# done.
# End time: Thu Mar  7 01:33:22 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/CHS_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/CHS_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/CHS_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:33:22 2024
# 12978 MiB RAM detected, ~11879 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 105 samples remaining.
# 105 samples (53 females, 52 males; 105 founders) remaining after main filters.
# done.
# 5603399 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6520082 variants remaining after main filters.
# Writing /content/1000g_by_population/CHS_all.fam ... done.
# Writing /content/1000g_by_population/CHS_all.bim ... done.
# done.
# End time: Thu Mar  7 01:35:38 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/CLM_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/CLM_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/CLM_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:35:39 2024
# 12978 MiB RAM detected, ~11878 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 94 samples remaining.
# 94 samples (51 females, 43 males; 94 founders) remaining after main filters.
# done.
# 2713357 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 9410124 variants remaining after main filters.
# Writing /content/1000g_by_population/CLM_all.fam ... done.
# Writing /content/1000g_by_population/CLM_all.bim ... done.
# done.
# End time: Thu Mar  7 01:38:03 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/ESN_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/ESN_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/ESN_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:38:03 2024
# 12978 MiB RAM detected, ~11864 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 99 samples remaining.
# 99 samples (45 females, 54 males; 99 founders) remaining after main filters.
# done.
# 1823017 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10300464 variants remaining after main filters.
# Writing /content/1000g_by_population/ESN_all.fam ... done.
# Writing /content/1000g_by_population/ESN_all.bim ... done.
# done.
# End time: Thu Mar  7 01:40:54 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/FIN_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/FIN_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/FIN_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:40:54 2024
# 12978 MiB RAM detected, ~11877 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 99 samples remaining.
# 99 samples (61 females, 38 males; 99 founders) remaining after main filters.
# done.
# 4498152 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7625329 variants remaining after main filters.
# Writing /content/1000g_by_population/FIN_all.fam ... done.
# Writing /content/1000g_by_population/FIN_all.bim ... done.
# done.
# End time: Thu Mar  7 01:44:52 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/GBR_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/GBR_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/GBR_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:44:52 2024
# 12978 MiB RAM detected, ~11851 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 91 samples remaining.
# 91 samples (45 females, 46 males; 91 founders) remaining after main filters.
# done.
# 4532400 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7591081 variants remaining after main filters.
# Writing /content/1000g_by_population/GBR_all.fam ... done.
# Writing /content/1000g_by_population/GBR_all.bim ... done.
# done.
# End time: Thu Mar  7 01:47:47 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/GIH_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/GIH_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/GIH_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:47:47 2024
# 12978 MiB RAM detected, ~11869 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 103 samples remaining.
# 103 samples (47 females, 56 males; 102 founders) remaining after main filters.
# done.
# 4532715 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7590766 variants remaining after main filters.
# Writing /content/1000g_by_population/GIH_all.fam ... done.
# Writing /content/1000g_by_population/GIH_all.bim ... done.
# done.
# End time: Thu Mar  7 01:50:26 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/GWD_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/GWD_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/GWD_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:50:26 2024
# 12978 MiB RAM detected, ~11861 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 113 samples remaining.
# 113 samples (58 females, 55 males; 113 founders) remaining after main filters.
# done.
# 1875727 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10247754 variants remaining after main filters.
# Writing /content/1000g_by_population/GWD_all.fam ... done.
# Writing /content/1000g_by_population/GWD_all.bim ... done.
# done.
# End time: Thu Mar  7 01:53:13 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/IBS_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/IBS_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/IBS_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:53:14 2024
# 12978 MiB RAM detected, ~11849 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 106 samples remaining.
# 106 samples (53 females, 53 males; 106 founders) remaining after main filters.
# done.
# 4497656 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7625825 variants remaining after main filters.
# Writing /content/1000g_by_population/IBS_all.fam ... done.
# Writing /content/1000g_by_population/IBS_all.bim ... done.
# done.
# End time: Thu Mar  7 01:55:51 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/ITU_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/ITU_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/ITU_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:55:51 2024
# 12978 MiB RAM detected, ~9796 available; reserving 6489 MiB for main workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 102 samples remaining.
# 102 samples (43 females, 59 males; 102 founders) remaining after main filters.
# done.
# 4538996 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7584485 variants remaining after main filters.
# Writing /content/1000g_by_population/ITU_all.fam ... done.
# Writing /content/1000g_by_population/ITU_all.bim ... done.
# done.
# End time: Thu Mar  7 01:58:25 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/JPT_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/JPT_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/JPT_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 01:58:25 2024
# 12978 MiB RAM detected, ~11846 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 104 samples remaining.
# 104 samples (48 females, 56 males; 104 founders) remaining after main filters.
# done.
# 5619812 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6503669 variants remaining after main filters.
# Writing /content/1000g_by_population/JPT_all.fam ... done.
# Writing /content/1000g_by_population/JPT_all.bim ... done.
# done.
# End time: Thu Mar  7 02:00:52 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/KHV_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/KHV_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/KHV_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 02:00:52 2024
# 12978 MiB RAM detected, ~11882 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 99 samples remaining.
# 99 samples (53 females, 46 males; 99 founders) remaining after main filters.
# done.
# 5259528 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6863953 variants remaining after main filters.
# Writing /content/1000g_by_population/KHV_all.fam ... done.
# Writing /content/1000g_by_population/KHV_all.bim ... done.
# done.
# End time: Thu Mar  7 02:03:35 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/LWK_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/LWK_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/LWK_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 02:03:35 2024
# 12978 MiB RAM detected, ~11859 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 99 samples remaining.
# 99 samples (55 females, 44 males; 99 founders) remaining after main filters.
# done.
# 1585869 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10537612 variants remaining after main filters.
# Writing /content/1000g_by_population/LWK_all.fam ... done.
# Writing /content/1000g_by_population/LWK_all.bim ... done.
# done.
# End time: Thu Mar  7 02:06:46 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/MSL_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/MSL_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/MSL_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 02:06:47 2024
# 12978 MiB RAM detected, ~11858 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 85 samples remaining.
# 85 samples (43 females, 42 males; 85 founders) remaining after main filters.
# done.
# 1826202 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10297279 variants remaining after main filters.
# Writing /content/1000g_by_population/MSL_all.fam ... done.
# Writing /content/1000g_by_population/MSL_all.bim ... done.
# done.
# End time: Thu Mar  7 02:09:35 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/MXL_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/MXL_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/MXL_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 02:09:35 2024
# 12978 MiB RAM detected, ~11851 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 64 samples remaining.
# 64 samples (32 females, 32 males; 64 founders) remaining after main filters.
# done.
# 4052522 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 8070959 variants remaining after main filters.
# Writing /content/1000g_by_population/MXL_all.fam ... done.
# Writing /content/1000g_by_population/MXL_all.bim ... done.
# done.
# End time: Thu Mar  7 02:12:17 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/PEL_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/PEL_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/PEL_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 02:12:17 2024
# 12978 MiB RAM detected, ~11852 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 85 samples remaining.
# 85 samples (44 females, 41 males; 85 founders) remaining after main filters.
# done.
# 4366885 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7756596 variants remaining after main filters.
# Writing /content/1000g_by_population/PEL_all.fam ... done.
# Writing /content/1000g_by_population/PEL_all.bim ... done.
# done.
# End time: Thu Mar  7 02:15:00 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/PJL_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/PJL_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/PJL_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 02:15:00 2024
# 12978 MiB RAM detected, ~11859 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 96 samples remaining.
# 96 samples (48 females, 48 males; 96 founders) remaining after main filters.
# done.
# 4138346 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7985135 variants remaining after main filters.
# Writing /content/1000g_by_population/PJL_all.fam ... done.
# Writing /content/1000g_by_population/PJL_all.bim ... done.
# done.
# End time: Thu Mar  7 02:17:39 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/PUR_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/PUR_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/PUR_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 02:17:39 2024
# 12978 MiB RAM detected, ~11856 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 104 samples remaining.
# 104 samples (50 females, 54 males; 104 founders) remaining after main filters.
# done.
# 2706563 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 9416918 variants remaining after main filters.
# Writing /content/1000g_by_population/PUR_all.fam ... done.
# Writing /content/1000g_by_population/PUR_all.bim ... done.
# done.
# End time: Thu Mar  7 02:20:28 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/STU_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/STU_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/STU_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 02:20:29 2024
# 12978 MiB RAM detected, ~11873 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 102 samples remaining.
# 102 samples (47 females, 55 males; 101 founders) remaining after main filters.
# done.
# 4541219 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7582262 variants remaining after main filters.
# Writing /content/1000g_by_population/STU_all.fam ... done.
# Writing /content/1000g_by_population/STU_all.bim ... done.
# done.
# End time: Thu Mar  7 02:23:45 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/TSI_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/TSI_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/TSI_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 02:23:45 2024
# 12978 MiB RAM detected, ~11841 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 107 samples remaining.
# 107 samples (54 females, 53 males; 107 founders) remaining after main filters.
# done.
# 4561860 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 7561621 variants remaining after main filters.
# Writing /content/1000g_by_population/TSI_all.fam ... done.
# Writing /content/1000g_by_population/TSI_all.bim ... done.
# done.
# End time: Thu Mar  7 02:26:43 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/1000g_by_population/YRI_all.log.
# Options in effect:
#   --bfile /content/1000g
#   --exclude exclude.snps
#   --keep /content/split_ids/by_population/YRI_all.txt
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/1000g_by_population/YRI_all
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Thu Mar  7 02:26:43 2024
# 12978 MiB RAM detected, ~11868 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from
# /content/1000g.fam.
# 12123481 variants loaded from /content/1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# --keep: 108 samples remaining.
# 108 samples (56 females, 52 males; 108 founders) remaining after main filters.
# done.
# 1931775 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 10191706 variants remaining after main filters.
# Writing /content/1000g_by_population/YRI_all.fam ... done.
# Writing /content/1000g_by_population/YRI_all.bim ... done.
# done.
# End time: Thu Mar  7 02:31:11 2024

# %%
! cp -rf 1000g_by_population/ /content/drive/MyDrive/CSE-284-Final-Project/data/
