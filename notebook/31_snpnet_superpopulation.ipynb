# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! wget https://s3.amazonaws.com/plink2-assets/alpha5/plink2_linux_x86_64_20240105.zip
! unzip plink2_linux_x86_64_20240105.zip
! ./plink2
# Out:
# --2024-03-11 06:39:06--  https://s3.amazonaws.com/plink2-assets/alpha5/plink2_linux_x86_64_20240105.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.245.214, 52.217.113.32, 52.216.218.112, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.245.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9266484 (8.8M) [application/zip]
# Saving to: ‘plink2_linux_x86_64_20240105.zip’
#
# plink2_linux_x86_64 100%[===================>]   8.84M  32.3MB/s    in 0.3s
#
# 2024-03-11 06:39:07 (32.3 MB/s) - ‘plink2_linux_x86_64_20240105.zip’ saved [9266484/9266484]
#
# Archive:  plink2_linux_x86_64_20240105.zip
#   inflating: plink2
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
#
#   plink2 <input flag(s)...> [command flag(s)...] [other flag(s)...]
#   plink2 --help [flag name(s)...]
#
# Commands include --rm-dup list, --make-bpgen, --export, --freq, --geno-counts,
# --sample-counts, --missing, --hardy, --het, --fst, --indep-pairwise, --ld,
# --sample-diff, --make-king, --king-cutoff, --pmerge, --pgen-diff,
# --write-samples, --write-snplist, --make-grm-list, --pca, --glm, --adjust-file,
# --gwas-ssf, --clump, --score, --variant-score, --genotyping-rate, --pgen-info,
# --validate, and --zst-decompress.
#
# "plink2 --help | more" describes all functions.

# %%
! apt-get install zstd
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 0s (1,472 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 121749 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
## Change runtype to R

# %%
remove.packages("snpnet")
# Out:
# Removing package from ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library("devtools")
install_github("junyangq/glmnetPlus")
install_github("chrchang/plink-ng", subdir="/2.0/cindex")
install_github("chrchang/plink-ng", subdir="/2.0/pgenlibr")
install_github("junyangq/snpnet")
# install_github("KengChiChang/snpnet")
# Out:
# Loading required package: usethis
#
# Skipping install of 'glmnetPlus' from a github remote, the SHA1 (755b0e58) has not changed since last install.
#   Use `force = TRUE` to force installation
#
# Skipping install of 'cindex' from a github remote, the SHA1 (558ffd32) has not changed since last install.
#   Use `force = TRUE` to force installation
#
# Skipping install of 'pgenlibr' from a github remote, the SHA1 (558ffd32) has not changed since last install.
#   Use `force = TRUE` to force installation
#
# Downloading GitHub repo junyangq/snpnet@HEAD
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/Rtmp9kJwu1/remotesbb546e329f02/junyangq-snpnet-0b76309/DESCRIPTION’ ... OK
# * preparing ‘snpnet’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# Omitted ‘LazyData’ from DESCRIPTION
# * building ‘snpnet_0.3.0.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
GDRIVE_DATA_DIR   = "/content/drive/MyDrive/CSE-284-Final-Project/data/"
GENO_DIR          = '/content/chr19_by_superpopulation/'
PHEN_OLD_DIR      = '/content/chr19_ldl_pheno/'
PHEN_DIR          = '/content/chr19_ldl_pheno_corrected/'
RESULT_DIR        = '/content/chr19_ldl_pheno_result/'
MODEL_DIR         = '/content/chr19_ldl_pheno_result/models/'
SCORE_DIR         = '/content/chr19_ldl_pheno_result/scores/'
system(paste0("mkdir ", GENO_DIR))
system(paste0("mkdir ", PHEN_DIR))
system(paste0("mkdir ", PHEN_OLD_DIR))
system(paste0("mkdir ", RESULT_DIR))
system(paste0("mkdir ", MODEL_DIR))
system(paste0("mkdir ", SCORE_DIR))

# %%
system(paste0("cp ", GDRIVE_DATA_DIR, "1000g_by_chrom/chr19.* . "))

# %%
system(paste0("cp -r ", GDRIVE_DATA_DIR, "split_ids/ ."))

# %%
system(paste0("cp -r ", GDRIVE_DATA_DIR, "chr19_ldl_pheno/*.pheno ", PHEN_OLD_DIR))

# %%
library("tidyverse")
library("glue")
library("snpnet")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
LOG_ID           = '2024-3-10-1'
POP_LIST         = c('EUR')
POWER_LIST       = c(-1)
HER_LIST         = c(0.9)
NUM_CAUSALS_LIST = c(512)
PHENO_RANGE      = '1-3'

CHR19             = '/content/chr19'
SPLIT_DIR         = '/content/split_ids/by_superpopulation'
GENO_DIR          = '/content/chr19_by_superpopulation'
PHEN_OLD_DIR      = '/content/chr19_ldl_pheno/'
PHEN_DIR          = '/content/chr19_ldl_pheno_corrected'
MODEL_DIR         = '/content/chr19_ldl_pheno_result/models'
SCORE_DIR         = '/content/chr19_ldl_pheno_result/scores'
RESULT_DIR        = '/content/chr19_ldl_pheno_result'
GDRIVE_RESULT_DIR = '/content/drive/MyDrive/CSE-284-Final-Project/data/BASIL/chr19_ldl_pheno'

pheno_col_names = paste0('PHENO', c(1:100))
for (POWER in POWER_LIST) {
        for (HER in HER_LIST) {
            for (NUM_CAUSALS in NUM_CAUSALS_LIST) {
                params = glue("power={POWER}_her={HER}_num-causals={NUM_CAUSALS}")
                pheno_file = glue("{PHEN_OLD_DIR}/{params}.pheno")
                # transform phenotype to suit snpnet inpu format
                pheno_df = read_delim(pheno_file,
                                        delim=' ', skip=1,
                                        col_names=c('FID', 'IID', pheno_col_names),
                                        col_types=paste0('cc', paste0(rep('n', 100), collapse=''))) |>
                                        select_if(~!(all(is.na(.)) | all(. == "")))
                    pheno_df = pheno_df |>
                        inner_join(pop_samples, by=c('IID')) |>
                        select(all_of(c("FID", "IID", "split", pheno_col_names)))
                    write_csv(pheno_df, glue("{PHEN_DIR}/{params}.phe"))
            }
        }
    }

for (POP in POP_LIST) {
    print(glue("-------------- Start: {POP} --------------"))
    # combine train test split
    pop_samples = rbind(
        read_delim(glue('{SPLIT_DIR}/{POP}_train.txt'),
                    delim=' ', col_names=c('FID', 'IID'), skip=1, col_types='cc') |>
                    mutate(split='train'),
        read_delim(glue('{SPLIT_DIR}/{POP}_val.txt'),
                    delim=' ', col_names=c('FID', 'IID'), skip=1, col_types='cc') |>
                    mutate(split='val'),
        read_delim(glue('{SPLIT_DIR}/{POP}_test.txt'),
                    delim=' ', col_names=c('FID', 'IID'), skip=1, col_types='cc') |>
                    mutate(split='test')) |>
        select(-FID)
    # generate pgen for superpopulation
    system(glue(
    "./plink2 \\
        --make-pgen vzs 'psam-cols=+fid' \\
        --bfile {CHR19} \\
        --const-fid 0 \\
        --keep {SPLIT_DIR}/{POP}_all.txt \\
        --out {GENO_DIR}/{POP}_all \\
        >> snpnet_{LOG_ID}.log"
        ))
    for (POWER in POWER_LIST) {
        for (HER in HER_LIST) {
            for (NUM_CAUSALS in NUM_CAUSALS_LIST) {
                params = glue("power={POWER}_her={HER}_num-causals={NUM_CAUSALS}")
                PHENO_INDEX_START        = as.integer(strsplit(PHENO_RANGE, '-')[[1]][1])
                PHENO_INDEX_END          = as.integer(strsplit(PHENO_RANGE, '-')[[1]][2])
                combined_result_file     = glue('{RESULT_DIR}/combined_result_{params}_pheno={PHENO_INDEX_START}-{PHENO_INDEX_END}.csv')
                combined_prediction_file = glue('{RESULT_DIR}/combined_predict_{params}_pheno={PHENO_INDEX_START}-{PHENO_INDEX_END}.csv')
                combined_result_data     = list()
                combined_prediction_data = list()
                # get models, one for each phenotype
                for (PHENO_INDEX in PHENO_INDEX_START:PHENO_INDEX_END) {
                    print(glue("---- Train: pop={POP}, power={POWER}, her={HER}, num-causals={NUM_CAUSALS}, pheno={PHENO_INDEX}"))
                    # train snpnet
                    fit_snpnet = snpnet(
                        genotype.pfile = glue('{GENO_DIR}/{POP}_all'),
                        phenotype.file = glue('{PHEN_DIR}/{params}.phe'),
                        phenotype = glue('PHENO{PHENO_INDEX}'),
                        family = "gaussian",
                        split.col = "split",
                        mem = 48000,  # amount of memory available (MB), recommended
                        configs = configs
                    )
                    # get predictions
                    pred_snpnet = predict_snpnet(
                        fit = fit_snpnet,
                        new_genotype_file = glue('{GENO_DIR}/{POP}_all'),
                        new_phenotype_file = glue('{PHEN_DIR}/{params}.phe'),
                        phenotype = glue('PHENO{PHENO_INDEX}'),
                        split_col = "split",
                        split_name = c("train", "val", "test"),
                        configs = configs
                        )
                    train_score = tail(as.vector(unlist(pred_snpnet$metric$train)), n=1)
                    print(glue("-- Train score {train_score}: pop={POP}, power={POWER}, her={HER}, num-causals={NUM_CAUSALS}, pheno={PHENO_INDEX}"))
                    val_score = tail(as.vector(unlist(pred_snpnet$metric$val)), n=1)
                    test_score = tail(as.vector(unlist(pred_snpnet$metric$test)), n=1)
                    print(glue("-- Test score {test_score}: pop={POP}, power={POWER}, her={HER}, num-causals={NUM_CAUSALS}, pheno={PHENO_INDEX}"))
                    # resulst to save
                    result_row = data.frame(
                        "population/superpopulation"=POP,
                        "power"=POWER,
                        "her"=HER,
                        "num_causals"=NUM_CAUSALS,
                        "pheno_num"=PHENO_INDEX,
                        "train"=train_score,
                        "val"=val_score,
                        "test"=test_score)
                    combined_result_data[[PHENO_INDEX]] = result_row
                    # prediction to save
                    m1 = do.call(rbind, strsplit(rownames(pred_snpnet$prediction$test), '_'))
                    IID = m1[, 2]
                    predict = as.vector(pred_snpnet$prediction$test[,ncol(pred_snpnet$prediction$test)])
                    actual = pred_snpnet$response$test
                    predict_df = data.frame(IID, predict, actual,
                                            pheno_num=PHENO_INDEX)
                    combined_prediction_data[[PHENO_INDEX]] = predict_df

                }

                # Write combined prediction data to file
                combined_prediction_df = bind_rows(combined_prediction_data)
                write_csv(combined_prediction_df, combined_prediction_file)
                print(glue("-- Combined prediction data has been written to: {combined_prediction_file}"))

                # Write combined result data to file
                combined_result_df = bind_rows(combined_result_data)
                write_csv(combined_result_df, combined_result_file)
                print(glue("-- Combined result data has been written to: {combined_result_file}"))

                system(glue("cp {combined_result_file} {GDRIVE_RESULT_DIR}"))
                system(glue("cp {combined_prediction_file} {GDRIVE_RESULT_DIR}"))
                system(glue("rm -rf {MODEL_DIR}/*"))

            }
        }
    }
    system(glue("rm -rf {GENO_DIR}/{POP}*"))
}
# Out:
# -------------- Start: EUR --------------
# ---- Train: pop=EUR, power=-1, her=0.9, num-causals=512, pheno=1
# [2024-03-11 11:28:19.529679 snpnet] Start snpnet
# [2024-03-11 11:28:19.530044 snpnet] Preprocessing start..
# [2024-03-11 11:28:20.998292 snpnet]   Preprocessing end. Time elapsed: 1.4686 secs
# [2024-03-11 11:28:20.999032 snpnet] Iteration 0
# [2024-03-11 11:28:21.00303 snpnet]     Start computeProduct()
# [2024-03-11 11:28:21.00303 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:28:22.168009 snpnet]         End plink2 --variant-score. Time elapsed: 1.165 secs
# [2024-03-11 11:28:22.19708 snpnet]       End computeProduct(). Time elapsed: 1.194 secs
#
# [2024-03-11 11:28:22.207466 snpnet] Iteration 1
# [2024-03-11 11:28:30.84804 snpnet]     Start computeProduct()
# [2024-03-11 11:28:30.84804 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:28:32.047466 snpnet]         End plink2 --variant-score. Time elapsed: 1.1994 secs
# [2024-03-11 11:28:32.093298 snpnet]       End computeProduct(). Time elapsed: 1.2453 secs
# [2024-03-11 11:28:32.869948 snpnet]   KKT check obj done ...
# [2024-03-11 11:28:33.384149 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0075 secs
# [2024-03-11 11:28:33.384632 snpnet] metric train
# [2024-03-11 11:28:33.385005 snpnet] metric val.
# [2024-03-11 11:28:33.869684 snpnet]   Training and validation metric:
# [2024-03-11 11:28:33.870166 snpnet]   - Lambda idx 1. Training: -4.23838688590195e-08. Validation: -0.0132657258898918
# [2024-03-11 11:28:33.870443 snpnet]   - Lambda idx 2. Training: 0.0132806172140441. Validation: -0.00362139222480518
# [2024-03-11 11:28:33.870654 snpnet]   - Lambda idx 3. Training: 0.0390951622697197. Validation: 0.0167373128867411
# [2024-03-11 11:28:33.870872 snpnet]   - Lambda idx 4. Training: 0.0653141870043058. Validation: 0.0367115462012546
# [2024-03-11 11:28:33.87109 snpnet]   - Lambda idx 5. Training: 0.0918169446190239. Validation: 0.0556111422772195
# [2024-03-11 11:28:33.871289 snpnet]   - Lambda idx 6. Training: 0.116841705219365. Validation: 0.0731333972689052
# [2024-03-11 11:28:33.871475 snpnet]   - Lambda idx 7. Training: 0.14275797129998. Validation: 0.0905303368809134
# [2024-03-11 11:28:33.87165 snpnet]   - Lambda idx 8. Training: 0.166365758857307. Validation: 0.106420444414146
# [2024-03-11 11:28:33.871824 snpnet]   - Lambda idx 9. Training: 0.187992207796184. Validation: 0.120965735249635
# [2024-03-11 11:28:33.872018 snpnet]   - Lambda idx 10. Training: 0.211750428671243. Validation: 0.140299162701886
# [2024-03-11 11:28:33.872206 snpnet]   End iteration 1. Time elapsed: 11.6647 secs
# [2024-03-11 11:28:33.872206 snpnet]     The total time since start. Time elapsed: 14.3425 secs
# [2024-03-11 11:28:33.873155 snpnet] stopping lag=8, max.val.1=0.10642 max.val.2=0.140299
# [2024-03-11 11:28:33.873365 snpnet] Iteration 2
# [2024-03-11 11:28:40.966821 snpnet]     Start computeProduct()
# [2024-03-11 11:28:40.966821 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:28:42.597397 snpnet]         End plink2 --variant-score. Time elapsed: 1.6306 secs
# [2024-03-11 11:28:42.645014 snpnet]       End computeProduct(). Time elapsed: 1.6782 secs
# [2024-03-11 11:28:42.824478 snpnet]   KKT check obj done ...
# [2024-03-11 11:28:43.366491 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0154 secs
# [2024-03-11 11:28:43.367332 snpnet] metric train
# [2024-03-11 11:28:43.367978 snpnet] metric val.
# [2024-03-11 11:28:44.125821 snpnet]   Training and validation metric:
# [2024-03-11 11:28:44.126313 snpnet]   - Lambda idx 11. Training: 0.234052544070091. Validation: 0.159202688372043
# [2024-03-11 11:28:44.126596 snpnet]   - Lambda idx 12. Training: 0.25454593394456. Validation: 0.176491985050089
# [2024-03-11 11:28:44.126811 snpnet]   - Lambda idx 13. Training: 0.275471542043377. Validation: 0.192915070266924
# [2024-03-11 11:28:44.12707 snpnet]   - Lambda idx 14. Training: 0.298574227865711. Validation: 0.209013062755623
# [2024-03-11 11:28:44.127272 snpnet]   - Lambda idx 15. Training: 0.322367599992628. Validation: 0.224058687970857
# [2024-03-11 11:28:44.127542 snpnet]   End iteration 2. Time elapsed: 10.2542 secs
# [2024-03-11 11:28:44.127542 snpnet]     The total time since start. Time elapsed: 24.5979 secs
# [2024-03-11 11:28:44.129056 snpnet] stopping lag=13, max.val.1=0.192915 max.val.2=0.224059
# [2024-03-11 11:28:44.129292 snpnet] Iteration 3
# [2024-03-11 11:28:51.471594 snpnet]     Start computeProduct()
# [2024-03-11 11:28:51.471594 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:28:52.76342 snpnet]         End plink2 --variant-score. Time elapsed: 1.2918 secs
# [2024-03-11 11:28:52.796341 snpnet]       End computeProduct(). Time elapsed: 1.3247 secs
# [2024-03-11 11:28:52.896863 snpnet]   KKT check obj done ...
# [2024-03-11 11:28:53.342529 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0134 secs
# [2024-03-11 11:28:53.343197 snpnet] metric train
# [2024-03-11 11:28:53.343613 snpnet] metric val.
# [2024-03-11 11:28:53.834249 snpnet]   Training and validation metric:
# [2024-03-11 11:28:53.834853 snpnet]   - Lambda idx 16. Training: 0.346443461159902. Validation: 0.238998575464243
# [2024-03-11 11:28:53.835204 snpnet]   - Lambda idx 17. Training: 0.370300284862747. Validation: 0.253949475759245
# [2024-03-11 11:28:53.83546 snpnet]   - Lambda idx 18. Training: 0.392631000940521. Validation: 0.268357306596903
# [2024-03-11 11:28:53.835683 snpnet]   - Lambda idx 19. Training: 0.414265928874614. Validation: 0.280471451978725
# [2024-03-11 11:28:53.835922 snpnet]   - Lambda idx 20. Training: 0.437935345461923. Validation: 0.289825523640351
# [2024-03-11 11:28:53.836172 snpnet]   End iteration 3. Time elapsed: 9.7069 secs
# [2024-03-11 11:28:53.836172 snpnet]     The total time since start. Time elapsed: 34.3065 secs
# [2024-03-11 11:28:53.837491 snpnet] stopping lag=18, max.val.1=0.268357 max.val.2=0.289826
# [2024-03-11 11:28:53.837744 snpnet] Iteration 4
# [2024-03-11 11:29:01.863682 snpnet]     Start computeProduct()
# [2024-03-11 11:29:01.863682 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:29:03.003771 snpnet]         End plink2 --variant-score. Time elapsed: 1.1401 secs
# [2024-03-11 11:29:03.03548 snpnet]       End computeProduct(). Time elapsed: 1.1718 secs
# [2024-03-11 11:29:03.155552 snpnet]   KKT check obj done ...
# [2024-03-11 11:29:03.486739 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0079 secs
# [2024-03-11 11:29:03.487265 snpnet] metric train
# [2024-03-11 11:29:03.4876 snpnet] metric val.
# [2024-03-11 11:29:03.991046 snpnet]   Training and validation metric:
# [2024-03-11 11:29:03.991511 snpnet]   - Lambda idx 21. Training: 0.461762523282723. Validation: 0.299437986902991
# [2024-03-11 11:29:03.991798 snpnet]   - Lambda idx 22. Training: 0.486383657957184. Validation: 0.309766104664699
# [2024-03-11 11:29:03.992055 snpnet]   - Lambda idx 23. Training: 0.511787778917844. Validation: 0.327297748871344
# [2024-03-11 11:29:03.992262 snpnet]   - Lambda idx 24. Training: 0.535695184924467. Validation: 0.343624034347621
# [2024-03-11 11:29:03.992456 snpnet]   - Lambda idx 25. Training: 0.558959052742912. Validation: 0.358604972181267
# [2024-03-11 11:29:03.99265 snpnet]   End iteration 4. Time elapsed: 10.1549 secs
# [2024-03-11 11:29:03.99265 snpnet]     The total time since start. Time elapsed: 44.463 secs
# [2024-03-11 11:29:03.993573 snpnet] stopping lag=23, max.val.1=0.327298 max.val.2=0.358605
# [2024-03-11 11:29:03.993717 snpnet] Iteration 5
# [2024-03-11 11:29:11.866419 snpnet]     Start computeProduct()
# [2024-03-11 11:29:11.866419 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:29:13.536701 snpnet]         End plink2 --variant-score. Time elapsed: 1.6703 secs
# [2024-03-11 11:29:13.583079 snpnet]       End computeProduct(). Time elapsed: 1.7167 secs
# [2024-03-11 11:29:13.703639 snpnet]   KKT check obj done ...
# [2024-03-11 11:29:14.153337 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0087 secs
# [2024-03-11 11:29:14.153979 snpnet] metric train
# [2024-03-11 11:29:14.154352 snpnet] metric val.
# [2024-03-11 11:29:14.695171 snpnet]   Training and validation metric:
# [2024-03-11 11:29:14.6957 snpnet]   - Lambda idx 26. Training: 0.581721994147121. Validation: 0.372278506732499
# [2024-03-11 11:29:14.696021 snpnet]   - Lambda idx 27. Training: 0.603717468413986. Validation: 0.384537604685181
# [2024-03-11 11:29:14.696243 snpnet]   - Lambda idx 28. Training: 0.625001846988313. Validation: 0.395128464333508
# [2024-03-11 11:29:14.696456 snpnet]   - Lambda idx 29. Training: 0.646001233907341. Validation: 0.403593604103405
# [2024-03-11 11:29:14.696668 snpnet]   - Lambda idx 30. Training: 0.666855337231592. Validation: 0.409207907700782
# [2024-03-11 11:29:14.696931 snpnet]   End iteration 5. Time elapsed: 10.7032 secs
# [2024-03-11 11:29:14.696931 snpnet]     The total time since start. Time elapsed: 55.1673 secs
# [2024-03-11 11:29:14.698031 snpnet] stopping lag=28, max.val.1=0.395128 max.val.2=0.409208
# [2024-03-11 11:29:14.698227 snpnet] Iteration 6
# [2024-03-11 11:29:21.913927 snpnet]     Start computeProduct()
# [2024-03-11 11:29:21.913927 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:29:23.22119 snpnet]         End plink2 --variant-score. Time elapsed: 1.3073 secs
# [2024-03-11 11:29:23.25181 snpnet]       End computeProduct(). Time elapsed: 1.3379 secs
# [2024-03-11 11:29:23.393595 snpnet]   KKT check obj done ...
# [2024-03-11 11:29:23.908855 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0152 secs
# [2024-03-11 11:29:23.909503 snpnet] metric train
# [2024-03-11 11:29:23.909839 snpnet] metric val.
# [2024-03-11 11:29:24.674938 snpnet]   Training and validation metric:
# [2024-03-11 11:29:24.67543 snpnet]   - Lambda idx 31. Training: 0.687366107820922. Validation: 0.415192126338283
# [2024-03-11 11:29:24.675665 snpnet]   - Lambda idx 32. Training: 0.707700377707428. Validation: 0.421451392812728
# [2024-03-11 11:29:24.67587 snpnet]   - Lambda idx 33. Training: 0.726962842666638. Validation: 0.427305274643597
# [2024-03-11 11:29:24.676104 snpnet]   - Lambda idx 34. Training: 0.745090263068702. Validation: 0.431911346788414
# [2024-03-11 11:29:24.676317 snpnet]   - Lambda idx 35. Training: 0.762158670210707. Validation: 0.435216113254439
# [2024-03-11 11:29:24.676497 snpnet]   End iteration 6. Time elapsed: 9.9783 secs
# [2024-03-11 11:29:24.676497 snpnet]     The total time since start. Time elapsed: 1.0858 mins
# [2024-03-11 11:29:24.677593 snpnet] stopping lag=33, max.val.1=0.427305 max.val.2=0.435216
# [2024-03-11 11:29:24.677858 snpnet] Iteration 7
# [2024-03-11 11:29:33.276162 snpnet]     Start computeProduct()
# [2024-03-11 11:29:33.276162 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:29:34.507258 snpnet]         End plink2 --variant-score. Time elapsed: 1.2311 secs
# [2024-03-11 11:29:34.55512 snpnet]       End computeProduct(). Time elapsed: 1.279 secs
# [2024-03-11 11:29:34.677233 snpnet]   KKT check obj done ...
# [2024-03-11 11:29:35.136055 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0102 secs
# [2024-03-11 11:29:35.136705 snpnet] metric train
# [2024-03-11 11:29:35.137103 snpnet] metric val.
# [2024-03-11 11:29:35.664069 snpnet]   Training and validation metric:
# [2024-03-11 11:29:35.664736 snpnet]   - Lambda idx 36. Training: 0.77832056951993. Validation: 0.437466784048894
# [2024-03-11 11:29:35.665125 snpnet]   - Lambda idx 37. Training: 0.79399079550716. Validation: 0.438998607336643
# [2024-03-11 11:29:35.665382 snpnet]   - Lambda idx 38. Training: 0.808911956303175. Validation: 0.439932237120811
# [2024-03-11 11:29:35.665608 snpnet]   - Lambda idx 39. Training: 0.8227973167291. Validation: 0.440091975437887
# [2024-03-11 11:29:35.665823 snpnet]   - Lambda idx 40. Training: 0.835664340556928. Validation: 0.440101345668701
# [2024-03-11 11:29:35.66608 snpnet]   End iteration 7. Time elapsed: 10.9882 secs
# [2024-03-11 11:29:35.66608 snpnet]     The total time since start. Time elapsed: 1.2689 mins
# [2024-03-11 11:29:35.667204 snpnet] stopping lag=38, max.val.1=0.439932 max.val.2=0.440101
# [2024-03-11 11:29:35.66736 snpnet] Iteration 8
# [2024-03-11 11:29:43.4958 snpnet]     Start computeProduct()
# [2024-03-11 11:29:43.4958 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:29:44.626881 snpnet]         End plink2 --variant-score. Time elapsed: 1.1311 secs
# [2024-03-11 11:29:44.677176 snpnet]       End computeProduct(). Time elapsed: 1.1814 secs
# [2024-03-11 11:29:44.818035 snpnet]   KKT check obj done ...
# [2024-03-11 11:29:45.155976 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0097 secs
# [2024-03-11 11:29:45.156477 snpnet] metric train
# [2024-03-11 11:29:45.156804 snpnet] metric val.
# [2024-03-11 11:29:45.701989 snpnet]   Training and validation metric:
# [2024-03-11 11:29:45.70264 snpnet]   - Lambda idx 41. Training: 0.847700569567258. Validation: 0.43946820518694
# [2024-03-11 11:29:45.703032 snpnet]   - Lambda idx 42. Training: 0.859061804402327. Validation: 0.438207258385279
# [2024-03-11 11:29:45.703353 snpnet]   - Lambda idx 43. Training: 0.869759558591482. Validation: 0.436446463202723
# [2024-03-11 11:29:45.703594 snpnet]   - Lambda idx 44. Training: 0.879809988837105. Validation: 0.435474093384206
# [2024-03-11 11:29:45.703815 snpnet]   - Lambda idx 45. Training: 0.889282862374332. Validation: 0.436113202078405
# [2024-03-11 11:29:45.704236 snpnet]   End iteration 8. Time elapsed: 10.0369 secs
# [2024-03-11 11:29:45.704236 snpnet]     The total time since start. Time elapsed: 1.4362 mins
# [2024-03-11 11:29:45.70544 snpnet] stopping lag=43, max.val.1=0.440101 max.val.2=0.436113
# [2024-03-11 11:29:45.705641 snpnet] Early stopped at iteration 8 (Lambda idx=40 ) with validation metric: 0.44010134566870.
# [2024-03-11 11:29:45.705801 snpnet]   Previous ones: 0.435474093384206, 0.436113202078405.
# [2024-03-11 11:29:45.705983 snpnet] End snpnet. Time elapsed: 1.4363 mins
# -- Train score 0.889282867066952: pop=EUR, power=-1, her=0.9, num-causals=512, pheno=1
# -- Test score 0.404553668517638: pop=EUR, power=-1, her=0.9, num-causals=512, pheno=1
# ---- Train: pop=EUR, power=-1, her=0.9, num-causals=512, pheno=2
# [2024-03-11 11:29:49.616147 snpnet] Start snpnet
# [2024-03-11 11:29:49.616423 snpnet] Preprocessing start..
# [2024-03-11 11:29:51.031668 snpnet]   Preprocessing end. Time elapsed: 1.4155 secs
# [2024-03-11 11:29:51.03233 snpnet] Iteration 0
# [2024-03-11 11:29:51.034897 snpnet]     Start computeProduct()
# [2024-03-11 11:29:51.034897 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:29:52.141352 snpnet]         End plink2 --variant-score. Time elapsed: 1.1065 secs
# [2024-03-11 11:29:52.193535 snpnet]       End computeProduct(). Time elapsed: 1.1586 secs
#
# [2024-03-11 11:29:52.209205 snpnet] Iteration 1
# [2024-03-11 11:29:59.767159 snpnet]     Start computeProduct()
# [2024-03-11 11:29:59.767159 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:30:01.147643 snpnet]         End plink2 --variant-score. Time elapsed: 1.3805 secs
# [2024-03-11 11:30:01.194854 snpnet]       End computeProduct(). Time elapsed: 1.4277 secs
# [2024-03-11 11:30:01.597849 snpnet]   KKT check obj done ...
# [2024-03-11 11:30:02.21347 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0081 secs
# [2024-03-11 11:30:02.21402 snpnet] metric train
# [2024-03-11 11:30:02.214413 snpnet] metric val.
# [2024-03-11 11:30:02.709061 snpnet]   Training and validation metric:
# [2024-03-11 11:30:02.709577 snpnet]   - Lambda idx 1. Training: -4.23838690810641e-08. Validation: -0.00198950053530633
# [2024-03-11 11:30:02.710037 snpnet]   - Lambda idx 2. Training: 0.0251335112339693. Validation: 0.0136584473915062
# [2024-03-11 11:30:02.710353 snpnet]   - Lambda idx 3. Training: 0.0632628895228788. Validation: 0.0431695125430994
# [2024-03-11 11:30:02.710592 snpnet]   - Lambda idx 4. Training: 0.0999816971262315. Validation: 0.070830702916481
# [2024-03-11 11:30:02.710809 snpnet]   - Lambda idx 5. Training: 0.133448285898021. Validation: 0.09592596216436
# [2024-03-11 11:30:02.71104 snpnet]   - Lambda idx 6. Training: 0.163941767234817. Validation: 0.118676294776893
# [2024-03-11 11:30:02.711231 snpnet]   - Lambda idx 7. Training: 0.191835285614834. Validation: 0.139380003056158
# [2024-03-11 11:30:02.711388 snpnet]   - Lambda idx 8. Training: 0.217439712816311. Validation: 0.158974829077037
# [2024-03-11 11:30:02.711553 snpnet]   - Lambda idx 9. Training: 0.240783128241203. Validation: 0.176787196107593
# [2024-03-11 11:30:02.711683 snpnet]   - Lambda idx 10. Training: 0.262075326677997. Validation: 0.192976720271683
# [2024-03-11 11:30:02.711785 snpnet]   End iteration 1. Time elapsed: 10.5026 secs
# [2024-03-11 11:30:02.711785 snpnet]     The total time since start. Time elapsed: 13.0956 secs
# [2024-03-11 11:30:02.71245 snpnet] stopping lag=8, max.val.1=0.158975 max.val.2=0.192977
# [2024-03-11 11:30:02.712567 snpnet] Iteration 2
# [2024-03-11 11:30:10.88686 snpnet]     Start computeProduct()
# [2024-03-11 11:30:10.88686 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:30:12.104546 snpnet]         End plink2 --variant-score. Time elapsed: 1.2177 secs
# [2024-03-11 11:30:12.136292 snpnet]       End computeProduct(). Time elapsed: 1.2494 secs
# [2024-03-11 11:30:12.244774 snpnet]   KKT check obj done ...
# [2024-03-11 11:30:12.584488 snpnet]     Time of prediction on validation matrix Time elapsed: 0.008 secs
# [2024-03-11 11:30:12.585014 snpnet] metric train
# [2024-03-11 11:30:12.585328 snpnet] metric val.
# [2024-03-11 11:30:13.087361 snpnet]   Training and validation metric:
# [2024-03-11 11:30:13.088172 snpnet]   - Lambda idx 11. Training: 0.282018154018812. Validation: 0.208583377701826
# [2024-03-11 11:30:13.088594 snpnet]   - Lambda idx 12. Training: 0.301288528819027. Validation: 0.224377882486806
# [2024-03-11 11:30:13.088924 snpnet]   - Lambda idx 13. Training: 0.320097681320575. Validation: 0.239128818033563
# [2024-03-11 11:30:13.08923 snpnet]   - Lambda idx 14. Training: 0.338649705715513. Validation: 0.254073966397494
# [2024-03-11 11:30:13.089492 snpnet]   - Lambda idx 15. Training: 0.359734164707664. Validation: 0.27067789434103
# [2024-03-11 11:30:13.089718 snpnet]   End iteration 2. Time elapsed: 10.3772 secs
# [2024-03-11 11:30:13.089718 snpnet]     The total time since start. Time elapsed: 23.4736 secs
# [2024-03-11 11:30:13.090486 snpnet] stopping lag=13, max.val.1=0.239129 max.val.2=0.270678
# [2024-03-11 11:30:13.090633 snpnet] Iteration 3
# [2024-03-11 11:30:20.178739 snpnet]     Start computeProduct()
# [2024-03-11 11:30:20.178739 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:30:21.759307 snpnet]         End plink2 --variant-score. Time elapsed: 1.5806 secs
# [2024-03-11 11:30:21.824624 snpnet]       End computeProduct(). Time elapsed: 1.6459 secs
# [2024-03-11 11:30:22.003334 snpnet]   KKT check obj done ...
# [2024-03-11 11:30:22.526906 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0133 secs
# [2024-03-11 11:30:22.527647 snpnet] metric train
# [2024-03-11 11:30:22.528155 snpnet] metric val.
# [2024-03-11 11:30:23.221881 snpnet]   Training and validation metric:
# [2024-03-11 11:30:23.222428 snpnet]   - Lambda idx 16. Training: 0.380597567965272. Validation: 0.286042716988371
# [2024-03-11 11:30:23.222708 snpnet]   - Lambda idx 17. Training: 0.401822190163438. Validation: 0.301002827897012
# [2024-03-11 11:30:23.222955 snpnet]   - Lambda idx 18. Training: 0.422379803230318. Validation: 0.314693236729523
# [2024-03-11 11:30:23.223177 snpnet]   - Lambda idx 19. Training: 0.444184303636266. Validation: 0.327836910869851
# [2024-03-11 11:30:23.223393 snpnet]   - Lambda idx 20. Training: 0.469642704422051. Validation: 0.344483046962939
# [2024-03-11 11:30:23.223594 snpnet]   End iteration 3. Time elapsed: 10.133 secs
# [2024-03-11 11:30:23.223594 snpnet]     The total time since start. Time elapsed: 33.6074 secs
# [2024-03-11 11:30:23.224557 snpnet] stopping lag=18, max.val.1=0.314693 max.val.2=0.344483
# [2024-03-11 11:30:23.224739 snpnet] Iteration 4
# [2024-03-11 11:30:30.857162 snpnet]     Start computeProduct()
# [2024-03-11 11:30:30.857162 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:30:31.923543 snpnet]         End plink2 --variant-score. Time elapsed: 1.0664 secs
# [2024-03-11 11:30:31.954052 snpnet]       End computeProduct(). Time elapsed: 1.0969 secs
# [2024-03-11 11:30:32.058517 snpnet]   KKT check obj done ...
# [2024-03-11 11:30:32.378239 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0081 secs
# [2024-03-11 11:30:32.378772 snpnet] metric train
# [2024-03-11 11:30:32.379145 snpnet] metric val.
# [2024-03-11 11:30:32.878282 snpnet]   Training and validation metric:
# [2024-03-11 11:30:32.878838 snpnet]   - Lambda idx 21. Training: 0.497475593068135. Validation: 0.362244559127458
# [2024-03-11 11:30:32.879202 snpnet]   - Lambda idx 22. Training: 0.52419281716836. Validation: 0.377320661700865
# [2024-03-11 11:30:32.87948 snpnet]   - Lambda idx 23. Training: 0.549130424804373. Validation: 0.390730448336028
# [2024-03-11 11:30:32.879717 snpnet]   - Lambda idx 24. Training: 0.572886507690448. Validation: 0.401654222173442
# [2024-03-11 11:30:32.879973 snpnet]   - Lambda idx 25. Training: 0.596142458797262. Validation: 0.410362325872048
# [2024-03-11 11:30:32.880165 snpnet]   End iteration 4. Time elapsed: 9.6554 secs
# [2024-03-11 11:30:32.880165 snpnet]     The total time since start. Time elapsed: 43.264 secs
# [2024-03-11 11:30:32.880858 snpnet] stopping lag=23, max.val.1=0.39073 max.val.2=0.410362
# [2024-03-11 11:30:32.881042 snpnet] Iteration 5
# [2024-03-11 11:30:40.337183 snpnet]     Start computeProduct()
# [2024-03-11 11:30:40.337183 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:30:41.445956 snpnet]         End plink2 --variant-score. Time elapsed: 1.1088 secs
# [2024-03-11 11:30:41.475095 snpnet]       End computeProduct(). Time elapsed: 1.1379 secs
# [2024-03-11 11:30:41.586956 snpnet]   KKT check obj done ...
# [2024-03-11 11:30:42.051378 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0089 secs
# [2024-03-11 11:30:42.052024 snpnet] metric train
# [2024-03-11 11:30:42.052385 snpnet] metric val.
# [2024-03-11 11:30:42.555813 snpnet]   Training and validation metric:
# [2024-03-11 11:30:42.556418 snpnet]   - Lambda idx 26. Training: 0.619362736381639. Validation: 0.418490065852607
# [2024-03-11 11:30:42.556725 snpnet]   - Lambda idx 27. Training: 0.642010931590665. Validation: 0.425160316730113
# [2024-03-11 11:30:42.557005 snpnet]   - Lambda idx 28. Training: 0.663495624547006. Validation: 0.429743377505205
# [2024-03-11 11:30:42.557231 snpnet]   - Lambda idx 29. Training: 0.683959567434379. Validation: 0.432552013369888
# [2024-03-11 11:30:42.557439 snpnet]   - Lambda idx 30. Training: 0.70359329427627. Validation: 0.434264294154474
# [2024-03-11 11:30:42.55764 snpnet]   End iteration 5. Time elapsed: 9.6766 secs
# [2024-03-11 11:30:42.55764 snpnet]     The total time since start. Time elapsed: 52.9415 secs
# [2024-03-11 11:30:42.558659 snpnet] stopping lag=28, max.val.1=0.429743 max.val.2=0.434264
# [2024-03-11 11:30:42.55881 snpnet] Iteration 6
# [2024-03-11 11:30:49.647684 snpnet]     Start computeProduct()
# [2024-03-11 11:30:49.647684 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:30:51.277014 snpnet]         End plink2 --variant-score. Time elapsed: 1.6293 secs
# [2024-03-11 11:30:51.334994 snpnet]       End computeProduct(). Time elapsed: 1.6873 secs
# [2024-03-11 11:30:51.492258 snpnet]   KKT check obj done ...
# [2024-03-11 11:30:51.991737 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0151 secs
# [2024-03-11 11:30:51.992442 snpnet] metric train
# [2024-03-11 11:30:51.992938 snpnet] metric val.
# [2024-03-11 11:30:52.734237 snpnet]   Training and validation metric:
# [2024-03-11 11:30:52.734762 snpnet]   - Lambda idx 31. Training: 0.722541782020675. Validation: 0.434738358657175
# [2024-03-11 11:30:52.735122 snpnet]   - Lambda idx 32. Training: 0.740948025063041. Validation: 0.436470991591607
# [2024-03-11 11:30:52.735373 snpnet]   - Lambda idx 33. Training: 0.758425200109529. Validation: 0.43881496654577
# [2024-03-11 11:30:52.735589 snpnet]   - Lambda idx 34. Training: 0.774768087817103. Validation: 0.440124989504745
# [2024-03-11 11:30:52.735818 snpnet]   - Lambda idx 35. Training: 0.790297933775002. Validation: 0.441189365905937
# [2024-03-11 11:30:52.73603 snpnet]   End iteration 6. Time elapsed: 10.1772 secs
# [2024-03-11 11:30:52.73603 snpnet]     The total time since start. Time elapsed: 1.052 mins
# [2024-03-11 11:30:52.736974 snpnet] stopping lag=33, max.val.1=0.438815 max.val.2=0.441189
# [2024-03-11 11:30:52.737196 snpnet] Iteration 7
# [2024-03-11 11:30:59.92674 snpnet]     Start computeProduct()
# [2024-03-11 11:30:59.92674 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:31:01.231053 snpnet]         End plink2 --variant-score. Time elapsed: 1.3043 secs
# [2024-03-11 11:31:01.265912 snpnet]       End computeProduct(). Time elapsed: 1.3392 secs
# [2024-03-11 11:31:01.368596 snpnet]   KKT check obj done ...
# [2024-03-11 11:31:01.687628 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0091 secs
# [2024-03-11 11:31:01.688163 snpnet] metric train
# [2024-03-11 11:31:01.688483 snpnet] metric val.
# [2024-03-11 11:31:02.228271 snpnet]   Training and validation metric:
# [2024-03-11 11:31:02.228796 snpnet]   - Lambda idx 36. Training: 0.804900061839192. Validation: 0.442349800348979
# [2024-03-11 11:31:02.229144 snpnet]   - Lambda idx 37. Training: 0.818587286155435. Validation: 0.441297786359419
# [2024-03-11 11:31:02.229375 snpnet]   - Lambda idx 38. Training: 0.831391434392203. Validation: 0.438991019322422
# [2024-03-11 11:31:02.22958 snpnet]   - Lambda idx 39. Training: 0.843570974245084. Validation: 0.436570799831759
# [2024-03-11 11:31:02.229778 snpnet]   - Lambda idx 40. Training: 0.855100538853636. Validation: 0.435431216044258
# [2024-03-11 11:31:02.230019 snpnet]   End iteration 7. Time elapsed: 9.4928 secs
# [2024-03-11 11:31:02.230019 snpnet]     The total time since start. Time elapsed: 1.2102 mins
# [2024-03-11 11:31:02.231042 snpnet] stopping lag=38, max.val.1=0.44235 max.val.2=0.436571
# [2024-03-11 11:31:02.231205 snpnet] Early stopped at iteration 7 (Lambda idx=36 ) with validation metric: 0.44234980034898.
# [2024-03-11 11:31:02.231318 snpnet]   Previous ones: 0.436570799831759, 0.435431216044258.
# [2024-03-11 11:31:02.231436 snpnet] End snpnet. Time elapsed: 1.2103 mins
# -- Train score 0.855100544995036: pop=EUR, power=-1, her=0.9, num-causals=512, pheno=2
# -- Test score 0.389514981202473: pop=EUR, power=-1, her=0.9, num-causals=512, pheno=2
# ---- Train: pop=EUR, power=-1, her=0.9, num-causals=512, pheno=3
# [2024-03-11 11:31:06.806762 snpnet] Start snpnet
# [2024-03-11 11:31:06.807072 snpnet] Preprocessing start..
# [2024-03-11 11:31:08.634657 snpnet]   Preprocessing end. Time elapsed: 1.8279 secs
# [2024-03-11 11:31:08.63551 snpnet] Iteration 0
# [2024-03-11 11:31:08.639639 snpnet]     Start computeProduct()
# [2024-03-11 11:31:08.639639 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:31:09.666001 snpnet]         End plink2 --variant-score. Time elapsed: 1.0264 secs
# [2024-03-11 11:31:09.703126 snpnet]       End computeProduct(). Time elapsed: 1.0635 secs
#
# [2024-03-11 11:31:09.713687 snpnet] Iteration 1
# [2024-03-11 11:31:15.872102 snpnet]     Start computeProduct()
# [2024-03-11 11:31:15.872102 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:31:17.115214 snpnet]         End plink2 --variant-score. Time elapsed: 1.2431 secs
# [2024-03-11 11:31:17.152008 snpnet]       End computeProduct(). Time elapsed: 1.2799 secs
# [2024-03-11 11:31:18.13887 snpnet]   KKT check obj done ...
# [2024-03-11 11:31:18.732349 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0152 secs
# [2024-03-11 11:31:18.73325 snpnet] metric train
# [2024-03-11 11:31:18.733853 snpnet] metric val.
# [2024-03-11 11:31:19.433315 snpnet]   Training and validation metric:
# [2024-03-11 11:31:19.433936 snpnet]   - Lambda idx 1. Training: -4.23838690810641e-08. Validation: -0.0187945696300413
# [2024-03-11 11:31:19.434195 snpnet]   - Lambda idx 2. Training: 0.0185734847442832. Validation: -0.0054801492960479
# [2024-03-11 11:31:19.434371 snpnet]   - Lambda idx 3. Training: 0.0415879892398904. Validation: 0.0087406770241496
# [2024-03-11 11:31:19.434534 snpnet]   - Lambda idx 4. Training: 0.069229377177692. Validation: 0.0278552898618158
# [2024-03-11 11:31:19.434705 snpnet]   - Lambda idx 5. Training: 0.0954680363401292. Validation: 0.0465949756049511
# [2024-03-11 11:31:19.434867 snpnet]   - Lambda idx 6. Training: 0.120109274832718. Validation: 0.0638997091578765
# [2024-03-11 11:31:19.435046 snpnet]   - Lambda idx 7. Training: 0.146429090478869. Validation: 0.0822991760943844
# [2024-03-11 11:31:19.435201 snpnet]   - Lambda idx 8. Training: 0.173691529204216. Validation: 0.103009826552709
# [2024-03-11 11:31:19.435355 snpnet]   - Lambda idx 9. Training: 0.198475748272559. Validation: 0.121912878554446
# [2024-03-11 11:31:19.435515 snpnet]   - Lambda idx 10. Training: 0.223977370750261. Validation: 0.143211291331354
# [2024-03-11 11:31:19.435668 snpnet]   End iteration 1. Time elapsed: 9.722 secs
# [2024-03-11 11:31:19.435668 snpnet]     The total time since start. Time elapsed: 12.6289 secs
# [2024-03-11 11:31:19.43655 snpnet] stopping lag=8, max.val.1=0.10301 max.val.2=0.143211
# [2024-03-11 11:31:19.436741 snpnet] Iteration 2
# [2024-03-11 11:31:26.59241 snpnet]     Start computeProduct()
# [2024-03-11 11:31:26.59241 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:31:27.675172 snpnet]         End plink2 --variant-score. Time elapsed: 1.0828 secs
# [2024-03-11 11:31:27.718787 snpnet]       End computeProduct(). Time elapsed: 1.1264 secs
# [2024-03-11 11:31:27.852602 snpnet]   KKT check obj done ...
# [2024-03-11 11:31:28.304226 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0089 secs
# [2024-03-11 11:31:28.304888 snpnet] metric train
# [2024-03-11 11:31:28.305347 snpnet] metric val.
# [2024-03-11 11:31:28.801078 snpnet]   Training and validation metric:
# [2024-03-11 11:31:28.801831 snpnet]   - Lambda idx 11. Training: 0.247805919193073. Validation: 0.16357538260135
# [2024-03-11 11:31:28.802343 snpnet]   - Lambda idx 12. Training: 0.270875942629593. Validation: 0.182422823273432
# [2024-03-11 11:31:28.802654 snpnet]   - Lambda idx 13. Training: 0.293790210159749. Validation: 0.200194876415362
# [2024-03-11 11:31:28.802859 snpnet]   - Lambda idx 14. Training: 0.31466823342754. Validation: 0.21649341558916
# [2024-03-11 11:31:28.803069 snpnet]   - Lambda idx 15. Training: 0.333693848148221. Validation: 0.231455557315931
# [2024-03-11 11:31:28.803235 snpnet]   End iteration 2. Time elapsed: 9.3665 secs
# [2024-03-11 11:31:28.803235 snpnet]     The total time since start. Time elapsed: 21.9965 secs
# [2024-03-11 11:31:28.803975 snpnet] stopping lag=13, max.val.1=0.200195 max.val.2=0.231456
# [2024-03-11 11:31:28.804153 snpnet] Iteration 3
# [2024-03-11 11:31:35.658091 snpnet]     Start computeProduct()
# [2024-03-11 11:31:35.658091 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:31:37.442291 snpnet]         End plink2 --variant-score. Time elapsed: 1.7842 secs
# [2024-03-11 11:31:37.474547 snpnet]       End computeProduct(). Time elapsed: 1.8165 secs
# [2024-03-11 11:31:37.583555 snpnet]   KKT check obj done ...
# [2024-03-11 11:31:37.956109 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0083 secs
# [2024-03-11 11:31:37.956751 snpnet] metric train
# [2024-03-11 11:31:37.95714 snpnet] metric val.
# [2024-03-11 11:31:38.456093 snpnet]   Training and validation metric:
# [2024-03-11 11:31:38.456814 snpnet]   - Lambda idx 16. Training: 0.353029576691361. Validation: 0.246427328049191
# [2024-03-11 11:31:38.457261 snpnet]   - Lambda idx 17. Training: 0.374055155199874. Validation: 0.258885858816979
# [2024-03-11 11:31:38.457583 snpnet]   - Lambda idx 18. Training: 0.394947139348005. Validation: 0.271154700247008
# [2024-03-11 11:31:38.457819 snpnet]   - Lambda idx 19. Training: 0.417317430813732. Validation: 0.281989350103599
# [2024-03-11 11:31:38.458032 snpnet]   - Lambda idx 20. Training: 0.44321218350494. Validation: 0.293337857079123
# [2024-03-11 11:31:38.458203 snpnet]   End iteration 3. Time elapsed: 9.6541 secs
# [2024-03-11 11:31:38.458203 snpnet]     The total time since start. Time elapsed: 31.6514 secs
# [2024-03-11 11:31:38.458918 snpnet] stopping lag=18, max.val.1=0.271155 max.val.2=0.293338
# [2024-03-11 11:31:38.459113 snpnet] Iteration 4
# [2024-03-11 11:31:44.740951 snpnet]     Start computeProduct()
# [2024-03-11 11:31:44.740951 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:31:45.922398 snpnet]         End plink2 --variant-score. Time elapsed: 1.1814 secs
# [2024-03-11 11:31:45.954855 snpnet]       End computeProduct(). Time elapsed: 1.2139 secs
# [2024-03-11 11:31:46.060658 snpnet]   KKT check obj done ...
# [2024-03-11 11:31:46.41122 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0077 secs
# [2024-03-11 11:31:46.411765 snpnet] metric train
# [2024-03-11 11:31:46.412114 snpnet] metric val.
# [2024-03-11 11:31:46.917042 snpnet]   Training and validation metric:
# [2024-03-11 11:31:46.917563 snpnet]   - Lambda idx 21. Training: 0.472770518846565. Validation: 0.308629120631457
# [2024-03-11 11:31:46.917852 snpnet]   - Lambda idx 22. Training: 0.501982174213573. Validation: 0.321847754137592
# [2024-03-11 11:31:46.918126 snpnet]   - Lambda idx 23. Training: 0.529727896312036. Validation: 0.334508720740546
# [2024-03-11 11:31:46.918363 snpnet]   - Lambda idx 24. Training: 0.556731653323211. Validation: 0.347973643395235
# [2024-03-11 11:31:46.918572 snpnet]   - Lambda idx 25. Training: 0.582330108310759. Validation: 0.361224817542993
# [2024-03-11 11:31:46.918767 snpnet]   End iteration 4. Time elapsed: 8.4597 secs
# [2024-03-11 11:31:46.918767 snpnet]     The total time since start. Time elapsed: 40.112 secs
# [2024-03-11 11:31:46.919738 snpnet] stopping lag=23, max.val.1=0.334509 max.val.2=0.361225
# [2024-03-11 11:31:46.919878 snpnet] Iteration 5
# [2024-03-11 11:31:54.77334 snpnet]     Start computeProduct()
# [2024-03-11 11:31:54.77334 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:31:55.903952 snpnet]         End plink2 --variant-score. Time elapsed: 1.1306 secs
# [2024-03-11 11:31:55.936382 snpnet]       End computeProduct(). Time elapsed: 1.163 secs
# [2024-03-11 11:31:56.039908 snpnet]   KKT check obj done ...
# [2024-03-11 11:31:56.439145 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0089 secs
# [2024-03-11 11:31:56.439781 snpnet] metric train
# [2024-03-11 11:31:56.440183 snpnet] metric val.
# [2024-03-11 11:31:56.956739 snpnet]   Training and validation metric:
# [2024-03-11 11:31:56.957509 snpnet]   - Lambda idx 26. Training: 0.607376002342661. Validation: 0.37251252356067
# [2024-03-11 11:31:56.957963 snpnet]   - Lambda idx 27. Training: 0.631039672569742. Validation: 0.382233426246142
# [2024-03-11 11:31:56.958284 snpnet]   - Lambda idx 28. Training: 0.653234052181375. Validation: 0.390021653428536
# [2024-03-11 11:31:56.958585 snpnet]   - Lambda idx 29. Training: 0.674520925404681. Validation: 0.394714767954737
# [2024-03-11 11:31:56.958861 snpnet]   - Lambda idx 30. Training: 0.694832840019055. Validation: 0.398380953019546
# [2024-03-11 11:31:56.959106 snpnet]   End iteration 5. Time elapsed: 10.0392 secs
# [2024-03-11 11:31:56.959106 snpnet]     The total time since start. Time elapsed: 50.1523 secs
# [2024-03-11 11:31:56.959997 snpnet] stopping lag=28, max.val.1=0.390022 max.val.2=0.398381
# [2024-03-11 11:31:56.960154 snpnet] Iteration 6
# [2024-03-11 11:32:03.997617 snpnet]     Start computeProduct()
# [2024-03-11 11:32:03.997617 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:32:05.798002 snpnet]         End plink2 --variant-score. Time elapsed: 1.8004 secs
# [2024-03-11 11:32:05.850094 snpnet]       End computeProduct(). Time elapsed: 1.8525 secs
# [2024-03-11 11:32:06.005785 snpnet]   KKT check obj done ...
# [2024-03-11 11:32:06.35506 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0087 secs
# [2024-03-11 11:32:06.355561 snpnet] metric train
# [2024-03-11 11:32:06.355883 snpnet] metric val.
# [2024-03-11 11:32:06.858405 snpnet]   Training and validation metric:
# [2024-03-11 11:32:06.858972 snpnet]   - Lambda idx 31. Training: 0.714170721578876. Validation: 0.402582308569628
# [2024-03-11 11:32:06.859286 snpnet]   - Lambda idx 32. Training: 0.732724956635159. Validation: 0.405862196276598
# [2024-03-11 11:32:06.859525 snpnet]   - Lambda idx 33. Training: 0.750109550328649. Validation: 0.408298716717142
# [2024-03-11 11:32:06.859745 snpnet]   - Lambda idx 34. Training: 0.766689236264855. Validation: 0.410081866166188
# [2024-03-11 11:32:06.859976 snpnet]   - Lambda idx 35. Training: 0.782745542385114. Validation: 0.409583870524109
# [2024-03-11 11:32:06.860182 snpnet]   End iteration 6. Time elapsed: 9.9 secs
# [2024-03-11 11:32:06.860182 snpnet]     The total time since start. Time elapsed: 1.0009 mins
# [2024-03-11 11:32:06.861184 snpnet] stopping lag=33, max.val.1=0.408299 max.val.2=0.410082
# [2024-03-11 11:32:06.861356 snpnet] Iteration 7
# [2024-03-11 11:32:13.509514 snpnet]     Start computeProduct()
# [2024-03-11 11:32:13.509514 snpnet]       Start plink2 --variant-score
# [2024-03-11 11:32:14.656116 snpnet]         End plink2 --variant-score. Time elapsed: 1.1466 secs
# [2024-03-11 11:32:14.693206 snpnet]       End computeProduct(). Time elapsed: 1.1837 secs
# [2024-03-11 11:32:14.8225 snpnet]   KKT check obj done ...
# [2024-03-11 11:32:15.288065 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0105 secs
# [2024-03-11 11:32:15.288856 snpnet] metric train
# [2024-03-11 11:32:15.289348 snpnet] metric val.
# [2024-03-11 11:32:15.814247 snpnet]   Training and validation metric:
# [2024-03-11 11:32:15.815022 snpnet]   - Lambda idx 36. Training: 0.798202385769397. Validation: 0.408293429781712
# [2024-03-11 11:32:15.815458 snpnet]   - Lambda idx 37. Training: 0.812713730324861. Validation: 0.40569183897155
# [2024-03-11 11:32:15.815796 snpnet]   - Lambda idx 38. Training: 0.826250417973619. Validation: 0.40439658648729
# [2024-03-11 11:32:15.816105 snpnet]   - Lambda idx 39. Training: 0.83883446881137. Validation: 0.403921930677035
# [2024-03-11 11:32:15.816353 snpnet]   - Lambda idx 40. Training: 0.850845613043538. Validation: 0.404360210724786
# [2024-03-11 11:32:15.816547 snpnet]   End iteration 7. Time elapsed: 8.9552 secs
# [2024-03-11 11:32:15.816547 snpnet]     The total time since start. Time elapsed: 1.1502 mins
# [2024-03-11 11:32:15.817394 snpnet] stopping lag=38, max.val.1=0.410082 max.val.2=0.40436
# [2024-03-11 11:32:15.817525 snpnet] Early stopped at iteration 7 (Lambda idx=34 ) with validation metric: 0.41008186616619.
# [2024-03-11 11:32:15.817656 snpnet]   Previous ones: 0.403921930677035, 0.404360210724786.
# [2024-03-11 11:32:15.817786 snpnet] End snpnet. Time elapsed: 1.1502 mins
# -- Train score 0.850845619365278: pop=EUR, power=-1, her=0.9, num-causals=512, pheno=3
# -- Test score 0.397720330074578: pop=EUR, power=-1, her=0.9, num-causals=512, pheno=3
# Error in eval(expr, envir, enclos): object 'combined_prediction_df' not found
# Traceback:
#
# 1. write_csv(combined_prediction_df, combined_prediction_file)
# 2. write_delim(x, file, delim = ",", na = na, append = append, col_names = col_names,
#  .     quote = quote, escape = escape, eol = eol, num_threads = num_threads,
#  .     progress = progress)
# 3. stopifnot(is.data.frame(x))
# 4. is.data.frame(x)

# %%
system(glue(
    "./plink2 \\
        --make-pgen vzs 'psam-cols=+fid' \\
        --bfile {CHR19} \\
        --const-fid 0 \\
        --keep {SPLIT_DIR}/{POP}_all.txt \\
        --out {GENO_DIR}/{POP}_all \\
        >> snpnet_{LOG_ID}.log"
        ))

# %%
configs = list(
  save = TRUE,  # save intermediate results per iteration (default FALSE)
  nCores = 2,  # number of cores available (default 1)
  niter = 30,  # max number of iterations (default 50)
  # prevIter = 15,  # if we want to start from some iteration saved in results.dir
  use.glmnetPlus = TRUE,  # recommended for faster computation
  verbose = FALSE,
  # early.stopping = FALSE,  # whether to stop based on validation performance (default TRUE)
  early.stopping = TRUE,
  # stopping.lag = 2,
  plink2.path = "./plink2",   # path to plink2 program
  zstdcat.path = "/usr/bin/zstdcat",  # path to zstdcat program
  # meta.dir = "meta/",
  # save.dir = "save/",
  results.dir = MODEL_DIR
)
# check if the provided paths are valid
for (name in names(configs)) {
  tryCatch(system(paste(configs[[name]], "-h"), ignore.stdout = T),
    condition = function(e) cat("Please add", configs[[name]], "to PATH, or modify the path in the configs list.")
  )
}
# Out:
# Please add TRUE to PATH, or modify the path in the configs list.Please add 2 to PATH, or modify the path in the configs list.Please add 30 to PATH, or modify the path in the configs list.Please add TRUE to PATH, or modify the path in the configs list.Please add FALSE to PATH, or modify the path in the configs list.Please add TRUE to PATH, or modify the path in the configs list.

# %%
PHENO_INDEX_START = as.integer(strsplit(PHENO_RANGE, '-')[[1]][1])
PHENO_INDEX_END   = as.integer(strsplit(PHENO_RANGE, '-')[[1]][2])
for (PHENO_INDEX in PHENO_INDEX_START:PHENO_INDEX_END) {

    fit_snpnet = snpnet(
        genotype.pfile = glue('{GENO_DIR}/{POP}_all'),
        phenotype.file = glue('{PHEN_DIR}/{params}.phe'),
        phenotype = glue('PHENO{PHENO_INDEX}'),
        family = "gaussian",
        split.col = "split",
        mem = 48000,  # amount of memory available (MB), recommended
        configs = configs
    )
}
# Out:
# [2024-03-11 10:04:34.151538 snpnet] Start snpnet
# [2024-03-11 10:04:34.152286 snpnet] Preprocessing start..
# Loading required namespace: glmnet
#
# Loading required namespace: glmnetPlus
#
# Registered S3 methods overwritten by 'glmnetPlus':
#   method            from
#   print.glmnet      glmnet
#   plot.glmnet       glmnet
#   plot.multnet      glmnet
#   plot.mrelnet      glmnet
#   predict.glmnet    glmnet
#   predict.lognet    glmnet
#   predict.elnet     glmnet
#   predict.coxnet    glmnet
#   predict.fishnet   glmnet
#   predict.mrelnet   glmnet
#   predict.multnet   glmnet
#   coef.glmnet       glmnet
#   coef.cv.glmnet    glmnet
#   predict.cv.glmnet glmnet
#   plot.cv.glmnet    glmnet
#   deviance.glmnet   glmnet
# [2024-03-11 10:04:38.76871 snpnet]   Preprocessing end. Time elapsed: 4.6172 secs
# [2024-03-11 10:04:38.770358 snpnet] Iteration 0
# [2024-03-11 10:04:38.780156 snpnet]     Start computeProduct()
# [2024-03-11 10:04:38.780156 snpnet]       Start plink2 --variant-score
# [2024-03-11 10:04:39.864111 snpnet]         End plink2 --variant-score. Time elapsed: 1.084 secs
# [2024-03-11 10:04:39.895556 snpnet]       End computeProduct(). Time elapsed: 1.1154 secs
#
# [2024-03-11 10:04:39.905731 snpnet] Iteration 1
# [2024-03-11 10:04:50.351413 snpnet]     Start computeProduct()
# [2024-03-11 10:04:50.351413 snpnet]       Start plink2 --variant-score
# [2024-03-11 10:04:51.497099 snpnet]         End plink2 --variant-score. Time elapsed: 1.1457 secs
# [2024-03-11 10:04:51.984183 snpnet]       End computeProduct(). Time elapsed: 1.6328 secs
# [2024-03-11 10:04:53.235527 snpnet]   KKT check obj done ...
# [2024-03-11 10:04:54.456009 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0166 secs
# [2024-03-11 10:04:54.456564 snpnet] metric train
# [2024-03-11 10:04:54.457372 snpnet] metric val.
# [2024-03-11 10:04:54.948073 snpnet]   Training and validation metric:
# [2024-03-11 10:04:54.948609 snpnet]   - Lambda idx 1. Training: -4.23838688590195e-08. Validation: -0.0132657258898918
# [2024-03-11 10:04:54.948907 snpnet]   - Lambda idx 2. Training: 0.0132806172140441. Validation: -0.00362139222480518
# [2024-03-11 10:04:54.949134 snpnet]   - Lambda idx 3. Training: 0.0390951622697197. Validation: 0.0167373128867411
# [2024-03-11 10:04:54.949337 snpnet]   - Lambda idx 4. Training: 0.0653141870043058. Validation: 0.0367115462012546
# [2024-03-11 10:04:54.949532 snpnet]   - Lambda idx 5. Training: 0.0918169446190239. Validation: 0.0556111422772195
# [2024-03-11 10:04:54.949717 snpnet]   - Lambda idx 6. Training: 0.116841705219365. Validation: 0.0731333972689052
# [2024-03-11 10:04:54.949929 snpnet]   - Lambda idx 7. Training: 0.14275797129998. Validation: 0.0905303368809134
# [2024-03-11 10:04:54.950128 snpnet]   - Lambda idx 8. Training: 0.166365758857307. Validation: 0.106420444414146
# [2024-03-11 10:04:54.950315 snpnet]   - Lambda idx 9. Training: 0.187992207796184. Validation: 0.120965735249635
# [2024-03-11 10:04:54.950499 snpnet]   - Lambda idx 10. Training: 0.211750428671243. Validation: 0.140299162701886
# [2024-03-11 10:04:54.950668 snpnet]   End iteration 1. Time elapsed: 15.0449 secs
# [2024-03-11 10:04:54.950668 snpnet]     The total time since start. Time elapsed: 20.7991 secs
# [2024-03-11 10:04:54.952044 snpnet] stopping lag=8, max.val.1=0.10642 max.val.2=0.140299
# [2024-03-11 10:04:54.952301 snpnet] Iteration 2
# [2024-03-11 10:05:03.426279 snpnet]     Start computeProduct()
# [2024-03-11 10:05:03.426279 snpnet]       Start plink2 --variant-score
# [2024-03-11 10:05:04.65064 snpnet]         End plink2 --variant-score. Time elapsed: 1.2244 secs
# [2024-03-11 10:05:04.684838 snpnet]       End computeProduct(). Time elapsed: 1.2586 secs
# [2024-03-11 10:05:04.901795 snpnet]   KKT check obj done ...
# [2024-03-11 10:05:05.329053 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0085 secs
# [2024-03-11 10:05:05.329673 snpnet] metric train
# [2024-03-11 10:05:05.330127 snpnet] metric val.
# [2024-03-11 10:05:05.81508 snpnet]   Training and validation metric:
# [2024-03-11 10:05:05.815847 snpnet]   - Lambda idx 11. Training: 0.234052544070091. Validation: 0.159202688372043
# [2024-03-11 10:05:05.816245 snpnet]   - Lambda idx 12. Training: 0.25454593394456. Validation: 0.176491985050089
# [2024-03-11 10:05:05.816533 snpnet]   - Lambda idx 13. Training: 0.275471542043377. Validation: 0.192915070266924
# [2024-03-11 10:05:05.81678 snpnet]   - Lambda idx 14. Training: 0.298574227865711. Validation: 0.209013062755623
# [2024-03-11 10:05:05.816985 snpnet]   - Lambda idx 15. Training: 0.322367599992628. Validation: 0.224058687970857
# [2024-03-11 10:05:05.817153 snpnet]   End iteration 2. Time elapsed: 10.8649 secs
# [2024-03-11 10:05:05.817153 snpnet]     The total time since start. Time elapsed: 31.6656 secs
# [2024-03-11 10:05:05.817872 snpnet] stopping lag=13, max.val.1=0.192915 max.val.2=0.224059
# [2024-03-11 10:05:05.81807 snpnet] Iteration 3
# [2024-03-11 10:05:13.915983 snpnet]     Start computeProduct()
# [2024-03-11 10:05:13.915983 snpnet]       Start plink2 --variant-score
# [2024-03-11 10:05:15.708572 snpnet]         End plink2 --variant-score. Time elapsed: 1.7926 secs
# [2024-03-11 10:05:15.774687 snpnet]       End computeProduct(). Time elapsed: 1.8587 secs
# [2024-03-11 10:05:16.111883 snpnet]   KKT check obj done ...
# [2024-03-11 10:05:16.484007 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0079 secs
# [2024-03-11 10:05:16.484623 snpnet] metric train
# [2024-03-11 10:05:16.484995 snpnet] metric val.
# [2024-03-11 10:05:16.98091 snpnet]   Training and validation metric:
# [2024-03-11 10:05:16.981533 snpnet]   - Lambda idx 16. Training: 0.346443461159902. Validation: 0.238998575464243
# [2024-03-11 10:05:16.981884 snpnet]   - Lambda idx 17. Training: 0.370300284862747. Validation: 0.253949475759245
# [2024-03-11 10:05:16.982152 snpnet]   - Lambda idx 18. Training: 0.392631000940521. Validation: 0.268357306596903
# [2024-03-11 10:05:16.982382 snpnet]   - Lambda idx 19. Training: 0.414265928874614. Validation: 0.280471451978725
# [2024-03-11 10:05:16.982617 snpnet]   - Lambda idx 20. Training: 0.437935345461923. Validation: 0.289825523640351
# [2024-03-11 10:05:16.982843 snpnet]   End iteration 3. Time elapsed: 11.1648 secs
# [2024-03-11 10:05:16.982843 snpnet]     The total time since start. Time elapsed: 42.8313 secs
# [2024-03-11 10:05:16.98412 snpnet] stopping lag=18, max.val.1=0.268357 max.val.2=0.289826
# [2024-03-11 10:05:16.984334 snpnet] Iteration 4
# [2024-03-11 10:05:24.05667 snpnet]     Start computeProduct()
# [2024-03-11 10:05:24.05667 snpnet]       Start plink2 --variant-score
# [2024-03-11 10:05:25.314751 snpnet]         End plink2 --variant-score. Time elapsed: 1.2581 secs
# [2024-03-11 10:05:25.347316 snpnet]       End computeProduct(). Time elapsed: 1.2906 secs
# [2024-03-11 10:05:25.540658 snpnet]   KKT check obj done ...
# [2024-03-11 10:05:25.826514 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0079 secs
# [2024-03-11 10:05:25.827045 snpnet] metric train
# [2024-03-11 10:05:25.827374 snpnet] metric val.
# [2024-03-11 10:05:26.375515 snpnet]   Training and validation metric:
# [2024-03-11 10:05:26.376002 snpnet]   - Lambda idx 21. Training: 0.461762523282723. Validation: 0.299437986902991
# [2024-03-11 10:05:26.376283 snpnet]   - Lambda idx 22. Training: 0.486383657957184. Validation: 0.309766104664699
# [2024-03-11 10:05:26.376495 snpnet]   - Lambda idx 23. Training: 0.511787778917844. Validation: 0.327297748871344
# [2024-03-11 10:05:26.3767 snpnet]   - Lambda idx 24. Training: 0.535695184924467. Validation: 0.343624034347621
# [2024-03-11 10:05:26.376912 snpnet]   - Lambda idx 25. Training: 0.558959052742912. Validation: 0.358604972181267
# [2024-03-11 10:05:26.377146 snpnet]   End iteration 4. Time elapsed: 9.3928 secs
# [2024-03-11 10:05:26.377146 snpnet]     The total time since start. Time elapsed: 52.2256 secs
# [2024-03-11 10:05:26.378212 snpnet] stopping lag=23, max.val.1=0.327298 max.val.2=0.358605
# [2024-03-11 10:05:26.378414 snpnet] Iteration 5
# [2024-03-11 10:05:35.644026 snpnet]     Start computeProduct()
# [2024-03-11 10:05:35.644026 snpnet]       Start plink2 --variant-score
# [2024-03-11 10:05:36.785742 snpnet]         End plink2 --variant-score. Time elapsed: 1.1417 secs
# [2024-03-11 10:05:36.816025 snpnet]       End computeProduct(). Time elapsed: 1.172 secs
# [2024-03-11 10:05:37.023278 snpnet]   KKT check obj done ...
# [2024-03-11 10:05:37.311527 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0082 secs
# [2024-03-11 10:05:37.312048 snpnet] metric train
# [2024-03-11 10:05:37.312362 snpnet] metric val.
# [2024-03-11 10:05:37.82806 snpnet]   Training and validation metric:
# [2024-03-11 10:05:37.828527 snpnet]   - Lambda idx 26. Training: 0.581721994147121. Validation: 0.372278506732499
# [2024-03-11 10:05:37.828792 snpnet]   - Lambda idx 27. Training: 0.603717468413986. Validation: 0.384537604685181
# [2024-03-11 10:05:37.829048 snpnet]   - Lambda idx 28. Training: 0.625001846988313. Validation: 0.395128464333508
# [2024-03-11 10:05:37.829269 snpnet]   - Lambda idx 29. Training: 0.646001233907341. Validation: 0.403593604103405
# [2024-03-11 10:05:37.829469 snpnet]   - Lambda idx 30. Training: 0.666855337231592. Validation: 0.409207907700782
# [2024-03-11 10:05:37.829676 snpnet]   End iteration 5. Time elapsed: 11.4513 secs
# [2024-03-11 10:05:37.829676 snpnet]     The total time since start. Time elapsed: 1.0613 mins
# [2024-03-11 10:05:37.83055 snpnet] stopping lag=28, max.val.1=0.395128 max.val.2=0.409208
# [2024-03-11 10:05:37.830681 snpnet] Iteration 6
# [2024-03-11 10:05:45.353698 snpnet]     Start computeProduct()
# [2024-03-11 10:05:45.353698 snpnet]       Start plink2 --variant-score
# [2024-03-11 10:05:47.075382 snpnet]         End plink2 --variant-score. Time elapsed: 1.7217 secs
# [2024-03-11 10:05:47.127006 snpnet]       End computeProduct(). Time elapsed: 1.7733 secs
# [2024-03-11 10:05:47.428321 snpnet]   KKT check obj done ...
# [2024-03-11 10:05:47.925475 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0157 secs
# [2024-03-11 10:05:47.926317 snpnet] metric train
# [2024-03-11 10:05:47.926929 snpnet] metric val.
# [2024-03-11 10:05:48.577397 snpnet]   Training and validation metric:
# [2024-03-11 10:05:48.577878 snpnet]   - Lambda idx 31. Training: 0.687366107820922. Validation: 0.415192126338283
# [2024-03-11 10:05:48.578195 snpnet]   - Lambda idx 32. Training: 0.707700377707428. Validation: 0.421451392812728
# [2024-03-11 10:05:48.578421 snpnet]   - Lambda idx 33. Training: 0.726962842666638. Validation: 0.427305274643597
# [2024-03-11 10:05:48.578628 snpnet]   - Lambda idx 34. Training: 0.745090263068702. Validation: 0.431911346788414
# [2024-03-11 10:05:48.578839 snpnet]   - Lambda idx 35. Training: 0.762158670210707. Validation: 0.435216113254439
# [2024-03-11 10:05:48.579073 snpnet]   End iteration 6. Time elapsed: 10.7484 secs
# [2024-03-11 10:05:48.579073 snpnet]     The total time since start. Time elapsed: 1.2405 mins
# [2024-03-11 10:05:48.580099 snpnet] stopping lag=33, max.val.1=0.427305 max.val.2=0.435216
# [2024-03-11 10:05:48.580291 snpnet] Iteration 7
# [2024-03-11 10:05:55.121751 snpnet]     Start computeProduct()
# [2024-03-11 10:05:55.121751 snpnet]       Start plink2 --variant-score
# [2024-03-11 10:05:56.241082 snpnet]         End plink2 --variant-score. Time elapsed: 1.1193 secs
# [2024-03-11 10:05:56.272652 snpnet]       End computeProduct(). Time elapsed: 1.1509 secs
# [2024-03-11 10:05:56.521326 snpnet]   KKT check obj done ...
# [2024-03-11 10:05:56.936679 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0096 secs
# [2024-03-11 10:05:56.937333 snpnet] metric train
# [2024-03-11 10:05:56.937706 snpnet] metric val.
# [2024-03-11 10:05:57.469941 snpnet]   Training and validation metric:
# [2024-03-11 10:05:57.470522 snpnet]   - Lambda idx 36. Training: 0.77832056951993. Validation: 0.437466784048894
# [2024-03-11 10:05:57.470826 snpnet]   - Lambda idx 37. Training: 0.79399079550716. Validation: 0.438998607336643
# [2024-03-11 10:05:57.471082 snpnet]   - Lambda idx 38. Training: 0.808911956303175. Validation: 0.439932237120811
# [2024-03-11 10:05:57.471293 snpnet]   - Lambda idx 39. Training: 0.8227973167291. Validation: 0.440091975437887
# [2024-03-11 10:05:57.471492 snpnet]   - Lambda idx 40. Training: 0.835664340556928. Validation: 0.440101345668701
# [2024-03-11 10:05:57.47168 snpnet]   End iteration 7. Time elapsed: 8.8914 secs
# [2024-03-11 10:05:57.47168 snpnet]     The total time since start. Time elapsed: 1.3887 mins
# [2024-03-11 10:05:57.472792 snpnet] stopping lag=38, max.val.1=0.439932 max.val.2=0.440101
# [2024-03-11 10:05:57.473044 snpnet] Iteration 8
# [2024-03-11 10:06:05.217223 snpnet]     Start computeProduct()
# [2024-03-11 10:06:05.217223 snpnet]       Start plink2 --variant-score
# [2024-03-11 10:06:06.482765 snpnet]         End plink2 --variant-score. Time elapsed: 1.2655 secs
# [2024-03-11 10:06:06.529253 snpnet]       End computeProduct(). Time elapsed: 1.312 secs
# [2024-03-11 10:06:06.749285 snpnet]   KKT check obj done ...
# [2024-03-11 10:06:07.063476 snpnet]     Time of prediction on validation matrix Time elapsed: 0.0101 secs
# [2024-03-11 10:06:07.064294 snpnet] metric train
# [2024-03-11 10:06:07.064643 snpnet] metric val.
# [2024-03-11 10:06:07.607092 snpnet]   Training and validation metric:
# [2024-03-11 10:06:07.607784 snpnet]   - Lambda idx 41. Training: 0.847700569567258. Validation: 0.43946820518694
# [2024-03-11 10:06:07.608173 snpnet]   - Lambda idx 42. Training: 0.859061804402327. Validation: 0.438207258385279
# [2024-03-11 10:06:07.608442 snpnet]   - Lambda idx 43. Training: 0.869759558591482. Validation: 0.436446463202723
# [2024-03-11 10:06:07.608686 snpnet]   - Lambda idx 44. Training: 0.879809988837105. Validation: 0.435474093384206
# [2024-03-11 10:06:07.60894 snpnet]   - Lambda idx 45. Training: 0.889282862374332. Validation: 0.436113202078405
# [2024-03-11 10:06:07.609201 snpnet]   End iteration 8. Time elapsed: 10.1362 secs
# [2024-03-11 10:06:07.609201 snpnet]     The total time since start. Time elapsed: 1.5576 mins
# [2024-03-11 10:06:07.610384 snpnet] stopping lag=43, max.val.1=0.440101 max.val.2=0.436113
# [2024-03-11 10:06:07.610592 snpnet] Early stopped at iteration 8 (Lambda idx=40 ) with validation metric: 0.44010134566870.
# [2024-03-11 10:06:07.610733 snpnet]   Previous ones: 0.435474093384206, 0.436113202078405.
# [2024-03-11 10:06:07.610862 snpnet] End snpnet. Time elapsed: 1.5577 mins

# %%
pred_snpnet = predict_snpnet(
  fit = fit_snpnet,
  new_genotype_file = glue('{GENO_DIR}/{POP}_all'),
  new_phenotype_file = glue('{PHEN_DIR}/{params}.phe'),
  phenotype = glue('PHENO{PHENO_INDEX}'),
  split_col = "split",
  split_name = c("train", "val", "test"),
  configs = configs
)

# %%
train_score = tail(as.vector(unlist(pred_snpnet$metric$train)), n=1)

# %%
val_score = tail(as.vector(unlist(pred_snpnet$metric$val)), n=1)

# %%
test_score = tail(as.vector(unlist(pred_snpnet$metric$test)), n=1)

# %%
combined_result_data = list()

result_row = data.frame(
    "population/superpopulation"=POP,
    "power"=POWER,
    "her"=HER,
    "num_causals"=NUM_CAUSALS,
    "pheno_num"=PHENO_INDEX,
    "train"=train_score,
    "val"=val_score,
    "test"=test_score)

combined_result_data[[PHENO_INDEX]] = result_row
combined_result_df = bind_rows(combined_result_data)
combined_result_df
# Out:
#   population.superpopulation power her num_causals pheno_num train
# 1 EUR                        -1    0.9 512         1         0.8892829
#   val       test
# 1 0.4361132 0.4045537

# %%
combined_result_data
# Out:
# [[1]]
#   population.superpopulation power her num_causals pheno_num     train
# 1                        EUR    -1 0.9         512         1 0.8892829
#         val      test
# 1 0.4361132 0.4045537

# %%
m1 = do.call(rbind, strsplit(rownames(pred_snpnet$prediction$test), '_'))
IID = m1[, 2]
predict = as.vector(pred_snpnet$prediction$test[,ncol(pred_snpnet$prediction$test)])
actual = pred_snpnet$response$test
predict_df = data.frame(IID, predict, actual,
                        pheno_num=PHENO_INDEX)
write_csv(predict_df)
# Out:
#    IID     predict      actual    pheno_num
# 1  HG00102  0.51495073   0.792442 1
# 2  HG00103  0.02075237   0.585911 1
# 3  HG00110 -0.21315916  -1.008965 1
# 4  HG00115  0.20748865  -0.318146 1
# 5  HG00131 -0.11147641   1.033428 1
# 6  HG00132  0.07907709   0.234816 1
# 7  HG00136  0.67604756  -0.810131 1
# 8  HG00139 -0.21344212   1.221630 1
# 9  HG00149 -0.42408451  -0.340724 1
# 10 HG00174  0.11832277  -0.678233 1
# 11 HG00187 -0.79422608  -0.478212 1
# 12 HG00188  0.05698335  -0.299454 1
# 13 HG00232 -0.13128994   0.344023 1
# 14 HG00233 -0.26843412  -0.174618 1
# 15 HG00244  0.11080959  -0.020464 1
# 16 HG00266  0.01069734  -0.926152 1
# 17 HG00267  0.16611470  -0.472721 1
# 18 HG00271  1.21000827   3.361278 1
# 19 HG00276 -0.68011919  -0.079868 1
# 20 HG00304  0.32236874  -0.024276 1
# 21 HG00310 -0.02552007  -0.339671 1
# 22 HG00319  0.29051147   0.862200 1
# 23 HG00325  1.38867337   3.458776 1
# 24 HG00327 -0.09506001   0.868757 1
# 25 HG00328 -0.53438409  -0.614563 1
# 26 HG00329  0.91100771   0.774474 1
# 27 HG00343 -0.43315330  -0.427361 1
# 28 HG00349  0.52864610   0.455067 1
# 29 HG00357 -0.35716973  -0.995614 1
# 30 HG00361  0.34626959   1.312791 1
# ⋮  ⋮       ⋮            ⋮         ⋮
# 53 NA11920 -0.032506586 -0.289839 1
# 54 NA11995  0.113690894 -1.349522 1
# 55 NA12043 -0.456862315 -1.459333 1
# 56 NA12154  1.899409356  4.393766 1
# 57 NA12342 -0.003317070 -0.263124 1
# 58 NA12716 -0.107237972  0.130898 1
# 59 NA12749 -0.242263887  0.709996 1
# 60 NA12751  0.633774318  0.458936 1
# 61 NA12761  0.047534365  0.817989 1
# 62 NA12778 -0.487505810 -1.346964 1
# 63 NA12874 -0.483234531 -0.365767 1
# 64 NA20506 -0.572078272  0.553743 1
# 65 NA20511 -0.047515269 -0.459349 1
# 66 NA20512  0.439175636  0.914565 1
# 67 NA20513  1.648719105  1.908848 1
# 68 NA20514 -0.145165348 -0.524946 1
# 69 NA20515 -0.218756985 -0.329600 1
# 70 NA20525 -0.694782931 -0.283609 1
# 71 NA20536 -0.513836623 -0.914713 1
# 72 NA20541  0.027412158 -1.100549 1
# 73 NA20542  0.274312596  0.788823 1
# 74 NA20760  0.049027225 -0.131185 1
# 75 NA20761  0.153345770  0.784149 1
# 76 NA20765  0.550735475  0.163098 1
# 77 NA20787 -0.832305938 -0.954510 1
# 78 NA20792  0.006682238 -0.266444 1
# 79 NA20796  0.624087798  0.889445 1
# 80 NA20799  0.405493983 -0.732217 1
# 81 NA20818 -0.936948045  0.430881 1
# 82 NA20819  0.333998088 -0.314127 1
