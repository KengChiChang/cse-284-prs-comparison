# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! wget https://www.dropbox.com/s/6ppo144ikdzery5/phase3_corrected.psam
# Out:
# --2024-03-10 08:45:22--  https://www.dropbox.com/s/6ppo144ikdzery5/phase3_corrected.psam
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/6ppo144ikdzery5/phase3_corrected.psam [following]
# --2024-03-10 08:45:22--  https://www.dropbox.com/s/raw/6ppo144ikdzery5/phase3_corrected.psam
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucac23b6aae8aa291d7fad9a8877.dl.dropboxusercontent.com/cd/0/inline/CO0vT4r3nidOtcqD82ZQKOHpOt16unmBdHyXIdtW_6GIUFNYdgGgwu0XSRVEYvVpKUWxncGWmbymL206z_mib5n1U9ibLATEofVPkArpFRQk7NkbeNHqHufUvDITipn_SPs/file# [following]
# ...

# %%
! wget https://s3.amazonaws.com/plink2-assets/alpha5/plink2_linux_x86_64_20240105.zip
! unzip plink2_linux_x86_64_20240105.zip
! ./plink2
# Out:
# --2024-03-10 08:45:38--  https://s3.amazonaws.com/plink2-assets/alpha5/plink2_linux_x86_64_20240105.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.9.230, 54.231.134.24, 16.182.42.216, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.9.230|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9266484 (8.8M) [application/zip]
# Saving to: ‘plink2_linux_x86_64_20240105.zip’
#
# plink2_linux_x86_64 100%[===================>]   8.84M  30.8MB/s    in 0.3s
#
# 2024-03-10 08:45:39 (30.8 MB/s) - ‘plink2_linux_x86_64_20240105.zip’ saved [9266484/9266484]
#
# Archive:  plink2_linux_x86_64_20240105.zip
#   inflating: plink2
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
#
#   plink2 <input flag(s)...> [command flag(s)...] [other flag(s)...]
#   plink2 --help [flag name(s)...]
#
# ...

# %%
! cp /content/drive/MyDrive/CSE-284-Final-Project/data/1000g_chr19_pruned/* .

# %%
sh = """

VCF=1000g_chr19_pruned.vcf.gz
OUT=1000g_chr19_pruned

./plink2 --make-bed \
    --vcf $VCF \
    --out $OUT

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to 1000g_chr19_pruned.log.
# Options in effect:
#   --make-bed
#   --out 1000g_chr19_pruned
#   --vcf 1000g_chr19_pruned.vcf.gz
#
# Start time: Sun Mar 10 08:52:01 2024
# 12978 MiB RAM detected, ~12012 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 17784 variants scanned.
# --vcf: 1000g_chr19_pruned-temporary.pgen +
# 1000g_chr19_pruned-temporary.pvar.zst + 1000g_chr19_pruned-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# 1000g_chr19_pruned-temporary.psam.
# 17784 variants loaded from 1000g_chr19_pruned-temporary.pvar.zst.
# Note: No phenotype data present.
# Writing 1000g_chr19_pruned.fam ... done.
# Writing 1000g_chr19_pruned.bim ...
# Error: 1000g_chr19_pruned.bim cannot contain multiallelic variants.
# ...

# %%
! head 1000g_chr19_pruned.bim
# Out:
# head: cannot open '1000g_chr19_pruned.bim' for reading: No such file or directory
