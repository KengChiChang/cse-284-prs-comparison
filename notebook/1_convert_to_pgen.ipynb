# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! wget https://s3.amazonaws.com/plink2-assets/alpha5/plink2_linux_x86_64_20240105.zip
! unzip plink2_linux_x86_64_20240105.zip
! ./plink2
# Out:
# --2024-03-06 01:55:05--  https://s3.amazonaws.com/plink2-assets/alpha5/plink2_linux_x86_64_20240105.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.203.200, 52.217.82.126, 54.231.224.32, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.203.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9266484 (8.8M) [application/zip]
# Saving to: ‘plink2_linux_x86_64_20240105.zip’
#
# plink2_linux_x86_64 100%[===================>]   8.84M  43.1MB/s    in 0.2s
#
# 2024-03-06 01:55:06 (43.1 MB/s) - ‘plink2_linux_x86_64_20240105.zip’ saved [9266484/9266484]
#
# Archive:  plink2_linux_x86_64_20240105.zip
#   inflating: plink2
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
#
#   plink2 <input flag(s)...> [command flag(s)...] [other flag(s)...]
#   plink2 --help [flag name(s)...]
#
# ...

# %%
sh = """

echo "." > exclude.snps

PREFIX=/content/drive/MyDrive/CSE-284-Final-Project/data

for CHROM in {1..22}
do
    VCF=${PREFIX}/vcf/ALL.chr${CHROM}.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
    OUT=${PREFIX}/pgen/ALL.chr${CHROM}.phase3.genotypes

    ./plink2 \
        --make-pgen vzs 'pvar-cols=' \
        --chr ${CHROM} \
        --max-alleles 2 \
        --maf 0.01 \
        --vcf $VCF \
        --double-id \
        --snps-only just-acgt \
        --rm-dup exclude-all \
        --exclude exclude.snps \
        --out $OUT
done

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/pgen/ALL.chr1.phase3.genotypes.log.
# Options in effect:
#   --chr 1
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/pgen/ALL.chr1.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr1.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 18:17:24 2024
# 12978 MiB RAM detected, ~12048 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 6468094 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/pgen/ALL.chr1.phase3.genotypes-temporary.pgen
# +
# ...

# %%
sh = """

PREFIX=/content/drive/MyDrive/CSE-284-Final-Project/data

VCF=${PREFIX}/test_data/CEU_chr19_normed.vcf.gz
OUT=${PREFIX}/test_data/CEU_chr19_normed

./plink2 \
    --chr 19 \
    --max-alleles 2 \
    --maf 0.01 \
    --vcf $VCF \
    --make-pgen vzs 'pvar-cols=' \
    --double-id \
    --out $OUT

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.log.
# Options in effect:
#   --chr 19
#   --double-id
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.vcf.gz
#
# Start time: Mon Mar  4 08:18:32 2024
# 12978 MiB RAM detected, ~11955 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 1830285 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.pvar.zst
# +
# ...

# %%
sh = """

PREFIX=/content/drive/MyDrive/CSE-284-Final-Project/data

VCF=${PREFIX}/test_data/GBR_chr19_normed.vcf.gz
OUT=${PREFIX}/test_data/GBR_chr19_normed

./plink2 \
    --chr 19 \
    --max-alleles 2 \
    --maf 0.01 \
    --vcf $VCF \
    --make-pgen vzs 'pvar-cols=' \
    --double-id \
    --out $OUT

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/GBR_chr19_normed.log.
# Options in effect:
#   --chr 19
#   --double-id
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/GBR_chr19_normed
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/GBR_chr19_normed.vcf.gz
#
# Start time: Wed Mar  6 01:55:27 2024
# 12978 MiB RAM detected, ~11996 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 1830285 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/GBR_chr19_normed-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/GBR_chr19_normed-temporary.pvar.zst
# +
# ...

# %%
! cp /content/drive/MyDrive/CSE-284-Final-Project/data/1000g_combined/1000g.* .

# %%
sh = """

echo "." > exclude.snps

BFILE=1000g
OUT=1000g_pgen

./plink2 \
    --make-pgen vzs 'pvar-cols=' \
    --max-alleles 2 \
    --maf 0.01 \
    --bfile $BFILE \
    --snps-only just-acgt \
    --rm-dup exclude-all \
    --exclude exclude.snps \
    --out $OUT

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to 1000g_pgen.log.
# Options in effect:
#   --bfile 1000g
#   --exclude exclude.snps
#   --maf 0.01
#   --make-pgen vzs pvar-cols=
#   --max-alleles 2
#   --out 1000g_pgen
#   --rm-dup exclude-all
#   --snps-only just-acgt
#
# Start time: Wed Mar  6 06:03:04 2024
# 12978 MiB RAM detected, ~11846 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# 2504 samples (1270 females, 1234 males; 2497 founders) loaded from 1000g.fam.
# 12123481 variants loaded from 1000g.bim.
# Note: No phenotype data present.
# --exclude: 12123481 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# done.
# 0 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 12123481 variants remaining after main filters.
# ...

# %%
! cp 1000g_pgen* /content/drive/MyDrive/CSE-284-Final-Project/data/1000g_combined/
