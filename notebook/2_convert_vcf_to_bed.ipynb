# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! wget https://s3.amazonaws.com/plink2-assets/alpha5/plink2_linux_x86_64_20240105.zip
! unzip plink2_linux_x86_64_20240105.zip
! ./plink2
# Out:
# --2024-03-04 06:26:00--  https://s3.amazonaws.com/plink2-assets/alpha5/plink2_linux_x86_64_20240105.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.168.85, 52.217.116.104, 52.216.38.160, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.168.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9266484 (8.8M) [application/zip]
# Saving to: ‘plink2_linux_x86_64_20240105.zip’
#
# plink2_linux_x86_64 100%[===================>]   8.84M  20.0MB/s    in 0.4s
#
# 2024-03-04 06:26:01 (20.0 MB/s) - ‘plink2_linux_x86_64_20240105.zip’ saved [9266484/9266484]
#
# Archive:  plink2_linux_x86_64_20240105.zip
#   inflating: plink2
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
#
#   plink2 <input flag(s)...> [command flag(s)...] [other flag(s)...]
#   plink2 --help [flag name(s)...]
#
# Commands include --rm-dup list, --make-bpgen, --export, --freq, --geno-counts,
# --sample-counts, --missing, --hardy, --het, --fst, --indep-pairwise, --ld,
# --sample-diff, --make-king, --king-cutoff, --pmerge, --pgen-diff,
# --write-samples, --write-snplist, --make-grm-list, --pca, --glm, --adjust-file,
# --gwas-ssf, --clump, --score, --variant-score, --genotyping-rate, --pgen-info,
# --validate, and --zst-decompress.
#
# "plink2 --help | more" describes all functions.

# %%
sh = """

PREFIX=/content/drive/MyDrive/CSE-284-Final-Project/data

VCF=${PREFIX}/test_data/CEU_chr19_normed.vcf.gz
OUT=${PREFIX}/test_data/CEU_chr19_normed

./plink2 \
    --chr 19 \
    --max-alleles 2 \
    --maf 0.01 \
    --vcf $VCF \
    --make-bed \
    --double-id \
    --out $OUT

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.log.
# Options in effect:
#   --chr 19
#   --double-id
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.vcf.gz
#
# Start time: Mon Mar  4 06:36:26 2024
# 12978 MiB RAM detected, ~12007 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 1830285 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.psam
# written.
# 99 samples (0 females, 0 males, 99 ambiguous; 99 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.psam.
# 1820139 out of 1830285 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.pvar.zst.
# Note: No phenotype data present.
# done.
# 1577639 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 242500 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.bed
# done.
# End time: Mon Mar  4 06:36:31 2024

# %%
sh = """

echo "." > exclude.snps

PREFIX=/content/drive/MyDrive/CSE-284-Final-Project/data

for CHROM in {1..22}
do
    VCF=${PREFIX}/vcf/ALL.chr${CHROM}.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
    OUT=${PREFIX}/bed/ALL.chr${CHROM}.phase3.genotypes

    ./plink2 \
        --make-bed \
        --chr ${CHROM} \
        --max-alleles 2 \
        --maf 0.01 \
        --vcf $VCF \
        --double-id \
        --snps-only just-acgt \
        --rm-dup exclude-all \
        --exclude exclude.snps \
        --out $OUT
done

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr1.phase3.genotypes.log.
# Options in effect:
#   --chr 1
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr1.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr1.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 09:41:45 2024
# 12978 MiB RAM detected, ~11879 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 6468094 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr1.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr1.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr1.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr1.phase3.genotypes-temporary.psam.
# 6196151 out of 6468094 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr1.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 6196151 variants remaining.
# --rm-dup: 26 duplicated IDs, 52 variants removed.
# done.
# 5252331 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 943768 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr1.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr1.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr1.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 09:46:24 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr2.phase3.genotypes.log.
# Options in effect:
#   --chr 2
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr2.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr2.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 09:46:25 2024
# 12978 MiB RAM detected, ~11854 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 7081600 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr2.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr2.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr2.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr2.phase3.genotypes-temporary.psam.
# 6786300 out of 7081600 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr2.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 6786300 variants remaining.
# --rm-dup: 39 duplicated IDs, 78 variants removed.
# done.
# 5778066 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1008156 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr2.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr2.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr2.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 09:51:40 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr3.phase3.genotypes.log.
# Options in effect:
#   --chr 3
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr3.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr3.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 09:51:40 2024
# 12978 MiB RAM detected, ~11876 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 5832276 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr3.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr3.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr3.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr3.phase3.genotypes-temporary.psam.
# 5584397 out of 5832276 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr3.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 5584397 variants remaining.
# --rm-dup: 4 duplicated IDs, 8 variants removed.
# done.
# 4729165 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 855224 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr3.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr3.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr3.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 09:56:05 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr4.phase3.genotypes.log.
# Options in effect:
#   --chr 4
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr4.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr4.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 09:56:05 2024
# 12978 MiB RAM detected, ~11862 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 5732585 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr4.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr4.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr4.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr4.phase3.genotypes-temporary.psam.
# 5480936 out of 5732585 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr4.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 5480936 variants remaining.
# --rm-dup: 9 duplicated IDs, 18 variants removed.
# done.
# 4604080 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 876838 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr4.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr4.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr4.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:00:23 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr5.phase3.genotypes.log.
# Options in effect:
#   --chr 5
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr5.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr5.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:00:23 2024
# 12978 MiB RAM detected, ~11869 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 5265763 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr5.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr5.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr5.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr5.phase3.genotypes-temporary.psam.
# 5037955 out of 5265763 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr5.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 5037955 variants remaining.
# --rm-dup: 3 duplicated IDs, 6 variants removed.
# done.
# 4279189 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 758760 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr5.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr5.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr5.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:04:22 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr6.phase3.genotypes.log.
# Options in effect:
#   --chr 6
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr6.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr6.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:04:22 2024
# 12978 MiB RAM detected, ~11851 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 5024119 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr6.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr6.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr6.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr6.phase3.genotypes-temporary.psam.
# 4800101 out of 5024119 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr6.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 4800101 variants remaining.
# --rm-dup: 8 duplicated IDs, 16 variants removed.
# done.
# 4006510 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 793575 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr6.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr6.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr6.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:08:14 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr7.phase3.genotypes.log.
# Options in effect:
#   --chr 7
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr7.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr7.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:08:14 2024
# 12978 MiB RAM detected, ~11859 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 4716715 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr7.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr7.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr7.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr7.phase3.genotypes-temporary.psam.
# 4517734 out of 4716715 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr7.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 4517734 variants remaining.
# Note: Skipping --rm-dup since no duplicate IDs are present.
# done.
# 3805729 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 712005 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr7.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr7.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr7.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:11:45 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr8.phase3.genotypes.log.
# Options in effect:
#   --chr 8
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr8.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr8.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:11:45 2024
# 12978 MiB RAM detected, ~11887 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 4597105 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr8.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr8.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr8.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr8.phase3.genotypes-temporary.psam.
# 4417368 out of 4597105 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr8.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 4417367 variants remaining.
# --rm-dup: 29 duplicated IDs, 58 variants removed.
# done.
# 3744477 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 672832 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr8.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr8.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr8.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:15:13 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr9.phase3.genotypes.log.
# Options in effect:
#   --chr 9
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr9.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr9.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:15:13 2024
# 12978 MiB RAM detected, ~11869 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 3560687 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr9.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr9.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr9.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr9.phase3.genotypes-temporary.psam.
# 3414848 out of 3560687 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr9.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 3414848 variants remaining.
# --rm-dup: 10 duplicated IDs, 20 variants removed.
# done.
# 2888834 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 525994 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr9.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr9.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr9.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:17:55 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr10.phase3.genotypes.log.
# Options in effect:
#   --chr 10
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr10.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr10.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:17:55 2024
# 12978 MiB RAM detected, ~11837 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 3992219 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr10.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr10.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr10.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr10.phase3.genotypes-temporary.psam.
# 3823786 out of 3992219 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr10.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 3823786 variants remaining.
# --rm-dup: 4 duplicated IDs, 8 variants removed.
# done.
# 3214752 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 609026 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr10.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr10.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr10.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:20:55 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr11.phase3.genotypes.log.
# Options in effect:
#   --chr 11
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr11.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr11.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:20:55 2024
# 12978 MiB RAM detected, ~11866 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 4045628 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr11.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr11.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr11.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr11.phase3.genotypes-temporary.psam.
# 3877543 out of 4045628 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr11.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 3877543 variants remaining.
# --rm-dup: 2 duplicated IDs, 4 variants removed.
# done.
# 3279276 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 598263 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr11.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr11.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr11.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:23:59 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr12.phase3.genotypes.log.
# Options in effect:
#   --chr 12
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr12.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr12.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:23:59 2024
# 12978 MiB RAM detected, ~11855 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 3868428 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr12.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr12.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr12.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr12.phase3.genotypes-temporary.psam.
# 3698098 out of 3868428 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr12.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 3697856 variants remaining.
# --rm-dup: 5 duplicated IDs, 10 variants removed.
# done.
# 3118015 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 579831 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr12.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr12.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr12.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:26:54 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr13.phase3.genotypes.log.
# Options in effect:
#   --chr 13
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr13.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr13.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:26:54 2024
# 12978 MiB RAM detected, ~11866 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 2857916 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr13.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr13.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr13.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr13.phase3.genotypes-temporary.psam.
# 2727881 out of 2857916 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr13.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 2727881 variants remaining.
# --rm-dup: 1 duplicated ID, 2 variants removed.
# done.
# 2294068 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 433811 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr13.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr13.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr13.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:29:05 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr14.phase3.genotypes.log.
# Options in effect:
#   --chr 14
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr14.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr14.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:29:05 2024
# 12978 MiB RAM detected, ~11851 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 2655067 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr14.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr14.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr14.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr14.phase3.genotypes-temporary.psam.
# 2539149 out of 2655067 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr14.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 2539149 variants remaining.
# --rm-dup: 2 duplicated IDs, 4 variants removed.
# done.
# 2144767 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 394378 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr14.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr14.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr14.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:31:08 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr15.phase3.genotypes.log.
# Options in effect:
#   --chr 15
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr15.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr15.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:31:08 2024
# 12978 MiB RAM detected, ~11862 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 2424689 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr15.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr15.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr15.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr15.phase3.genotypes-temporary.psam.
# 2320474 out of 2424689 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr15.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 2320474 variants remaining.
# --rm-dup: 26 duplicated IDs, 52 variants removed.
# done.
# 1965938 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 354484 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr15.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr15.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr15.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:32:59 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr16.phase3.genotypes.log.
# Options in effect:
#   --chr 16
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr16.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr16.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:32:59 2024
# 12978 MiB RAM detected, ~11865 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 2697949 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr16.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr16.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr16.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr16.phase3.genotypes-temporary.psam.
# 2596072 out of 2697949 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr16.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 2596072 variants remaining.
# --rm-dup: 7 duplicated IDs, 14 variants removed.
# done.
# 2217319 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 378739 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr16.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr16.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr16.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:35:03 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr17.phase3.genotypes.log.
# Options in effect:
#   --chr 17
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr17.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr17.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:35:03 2024
# 12978 MiB RAM detected, ~11855 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 2329288 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr17.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr17.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr17.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr17.phase3.genotypes-temporary.psam.
# 2227080 out of 2329288 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr17.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 2227079 variants remaining.
# --rm-dup: 5 duplicated IDs, 10 variants removed.
# done.
# 1898171 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 328898 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr17.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr17.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr17.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:36:50 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr18.phase3.genotypes.log.
# Options in effect:
#   --chr 18
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr18.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr18.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:36:50 2024
# 12978 MiB RAM detected, ~11854 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 2267185 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr18.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr18.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr18.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr18.phase3.genotypes-temporary.psam.
# 2171378 out of 2267185 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr18.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 2171378 variants remaining.
# --rm-dup: 2 duplicated IDs, 4 variants removed.
# done.
# 1827512 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 343862 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr18.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr18.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr18.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:38:36 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr19.phase3.genotypes.log.
# Options in effect:
#   --chr 19
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr19.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr19.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:38:36 2024
# 12978 MiB RAM detected, ~11882 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 1832506 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr19.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr19.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr19.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr19.phase3.genotypes-temporary.psam.
# 1751878 out of 1832506 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr19.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 1751878 variants remaining.
# --rm-dup: 2 duplicated IDs, 4 variants removed.
# done.
# 1470142 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 281732 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr19.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr19.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr19.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:40:03 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr20.phase3.genotypes.log.
# Options in effect:
#   --chr 20
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr20.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr20.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:40:03 2024
# 12978 MiB RAM detected, ~11816 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 1812841 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr20.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr20.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr20.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr20.phase3.genotypes-temporary.psam.
# 1739315 out of 1812841 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr20.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 1739315 variants remaining.
# --rm-dup: 1 duplicated ID, 2 variants removed.
# done.
# 1473276 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 266037 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr20.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr20.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr20.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:41:30 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr21.phase3.genotypes.log.
# Options in effect:
#   --chr 21
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr21.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr21.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:41:30 2024
# 12978 MiB RAM detected, ~11800 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 1105538 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr21.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr21.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr21.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr21.phase3.genotypes-temporary.psam.
# 1054447 out of 1105538 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr21.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 1054447 variants remaining.
# --rm-dup: 1 duplicated ID, 2 variants removed.
# done.
# 884372 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 170073 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr21.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr21.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr21.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:42:22 2024
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr22.phase3.genotypes.log.
# Options in effect:
#   --chr 22
#   --double-id
#   --exclude exclude.snps
#   --maf 0.01
#   --make-bed
#   --max-alleles 2
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr22.phase3.genotypes
#   --rm-dup exclude-all
#   --snps-only just-acgt
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/vcf/ALL.chr22.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
#
# Start time: Mon Mar  4 10:42:22 2024
# 12978 MiB RAM detected, ~11803 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 1103547 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr22.phase3.genotypes-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr22.phase3.genotypes-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr22.phase3.genotypes-temporary.psam
# written.
# 2504 samples (0 females, 0 males, 2504 ambiguous; 2504 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr22.phase3.genotypes-temporary.psam.
# 1055454 out of 1103547 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr22.phase3.genotypes-temporary.pvar.zst.
# Note: No phenotype data present.
# --exclude: 1055454 variants remaining.
# --rm-dup: 2 duplicated IDs, 4 variants removed.
# done.
# 884502 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 170948 variants remaining after main filters.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr22.phase3.genotypes.fam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr22.phase3.genotypes.bim
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/bed/ALL.chr22.phase3.genotypes.bed
# done.
# End time: Mon Mar  4 10:43:15 2024

# %%
sh = """

PREFIX=/content/drive/MyDrive/CSE-284-Final-Project/data

VCF=${PREFIX}/test_data/CEU_chr19_normed.vcf.gz
OUT=${PREFIX}/test_data/CEU_chr19_normed

./plink2 \
    --vcf $VCF \
    --make-pgen vzs \
    --double-id \
    --out $OUT

"""
with open('script.sh', 'w') as file:
  file.write(sh)

! bash script.sh
# Out:
# PLINK v2.00a5.10LM 64-bit Intel (5 Jan 2024)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.log.
# Options in effect:
#   --double-id
#   --make-pgen vzs
#   --out /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed
#   --vcf /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.vcf.gz
#
# Start time: Mon Mar  4 03:30:26 2024
# 12978 MiB RAM detected, ~11978 available; reserving 6489 MiB for main
# workspace.
# Using up to 2 compute threads.
# --vcf: 1830285 variants scanned.
# --vcf:
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.pgen
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.pvar.zst
# +
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.psam
# written.
# 99 samples (0 females, 0 males, 99 ambiguous; 99 founders) loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.psam.
# 1830285 variants loaded from
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed-temporary.pvar.zst.
# Note: No phenotype data present.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.psam
# ... done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.pvar.zst
# done.
# Writing
# /content/drive/MyDrive/CSE-284-Final-Project/data/test_data/CEU_chr19_normed.pgen
# done.
# End time: Mon Mar  4 03:30:35 2024
